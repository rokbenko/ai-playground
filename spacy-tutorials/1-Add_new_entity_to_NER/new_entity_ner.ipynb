# %%
# We will use spaCy for NER and its pre-trained "en_core_web_lg" model.

# %%
# !python -m spacy download en_core_web_lg

# %%
import spacy

# Load the spaCy pre-trained model
nlp = spacy.load("en_core_web_lg")

# %%
# First, we want to make sure that we can read the sample.txt file.

# %%
# Open the file named "sample.txt" in read mode with UTF-8 encoding
with open("sample.txt", "r", encoding="utf-8") as file:
    # Read all lines from the file and store them in the 'articles' list
    articles = file.readlines()

# Print the first 5 articles or all articles if there are fewer than 5
for i in range(min(5, len(articles))):
    # Print the article number and the content of the article
    print(f"Article {i + 1}:\n{articles[i]}")

    # Print a separator line between articles for better readability
    print("-----\n")
# Out:
# Article 1:
# @fansoniclove Gold the Tenrec
#
# -----
#
# Article 2:
# Tokyo-bound Sampson sets Aust rifle record. Shooter Dane Sampson has struck career-best form as he builds towards a third Olympics, setting a national record while winning the 50m rifle event at the South Australia championships. Sampson registered a score of 462 points to claim gold in the three positions event. The performance bettered Sampson's own national record of 460.7 points, which he achieved at last month's Wingfield grand prix. The score was also notably higher than what Italy's Niccolo Campriani (458.8) and Poland's Tomasz Bartnik (460.4) produced to win gold at the 2016 Olympics and 2018 world championships respectively. "It's good to be shooting PBs at this stage. It was a world-class finals score," Sampson said, having previously competed at the 2012 and 2016 Olympics. "You are unlikely to lose many competitions with that score. "I definitely feel that I am getting better and better and I am tracking well for Tokyo." Sampson and other members of Australia's shooting team for the 2021 Olympics are set to come together for a pre-Games camp on July 4-19. The camp is intended to mimic the biosecurity bubble and strict protocols that await in Tokyo.
#
# -----
#
# Article 3:
# Originally posted by cordingup ↑ I see very interesting says the drill hole 33 now at 688 m so thats 88 m past the planned depth should mean they are still in mineralisation? Also i see in the tenements list those other permits around the MCB area they are still pursuing under appeal i guess the appeal is regards large sections of those falling into a National Park ??? One of those tenements from my reckoning hosts a copper gold resource another has a copper prospect. Expand That does sound promising. Gap up on open
#
# -----
#
# Article 4:
# "US 500 Futures Discussions. Hey guys what is gold's history in May?
#
# -----
#
# Article 5:
# Good time to invest in gold?"
#
# -----

# %%
# The first five articles were printed successfully. Now we will simply look for the strings "gold" or "silver" and print the number of articles containing these strings. Also, we want to print the articles themselves.

# %%
def entity_matcher(article):
    # Process the article using spaCy
    doc = nlp(article)

    # Check if "gold" or "silver" is present in the article
    gold_present = any(token.text.lower() == "gold" for token in doc)
    silver_present = any(token.text.lower() == "silver" for token in doc)

    return gold_present, silver_present

gold_count = 0
silver_count = 0

# Lists to store articles containing "gold" and "silver"
gold_articles = []
silver_articles = []

# Iterate through each article in the 'articles' list
for article in articles:
    gold_present, silver_present = entity_matcher(article)

    # Check if "gold" is present in the article
    if gold_present:
        gold_count += 1
        gold_articles.append(article)

    # Check if "silver" is present in the article
    if silver_present:
        silver_count += 1
        silver_articles.append(article)

# Print the number of articles containing 'gold' and 'silver'
print("Number of articles containing 'gold':", gold_count)
print("Number of articles containing 'silver':", silver_count)

# Print the first 5 articles containing "gold"
print("\nFirst 5 articles containing 'gold':")
for i, article in enumerate(gold_articles[:5], start=1):
    print(f"{i}. {article}")

# Print the first 5 articles containing "silver"
print("\nFirst 5 articles containing 'silver':")
for i, article in enumerate(silver_articles[:5], start=1):
    print(f"{i}. {article}")
# Out:
# Number of articles containing 'gold': 602
# Number of articles containing 'silver': 99
#
# First 5 articles containing 'gold':
# 1. @fansoniclove Gold the Tenrec
#
# 2. Tokyo-bound Sampson sets Aust rifle record. Shooter Dane Sampson has struck career-best form as he builds towards a third Olympics, setting a national record while winning the 50m rifle event at the South Australia championships. Sampson registered a score of 462 points to claim gold in the three positions event. The performance bettered Sampson's own national record of 460.7 points, which he achieved at last month's Wingfield grand prix. The score was also notably higher than what Italy's Niccolo Campriani (458.8) and Poland's Tomasz Bartnik (460.4) produced to win gold at the 2016 Olympics and 2018 world championships respectively. "It's good to be shooting PBs at this stage. It was a world-class finals score," Sampson said, having previously competed at the 2012 and 2016 Olympics. "You are unlikely to lose many competitions with that score. "I definitely feel that I am getting better and better and I am tracking well for Tokyo." Sampson and other members of Australia's shooting team for the 2021 Olympics are set to come together for a pre-Games camp on July 4-19. The camp is intended to mimic the biosecurity bubble and strict protocols that await in Tokyo.
#
# 3. Originally posted by cordingup ↑ I see very interesting says the drill hole 33 now at 688 m so thats 88 m past the planned depth should mean they are still in mineralisation? Also i see in the tenements list those other permits around the MCB area they are still pursuing under appeal i guess the appeal is regards large sections of those falling into a National Park ??? One of those tenements from my reckoning hosts a copper gold resource another has a copper prospect. Expand That does sound promising. Gap up on open
#
# 4. "US 500 Futures Discussions. Hey guys what is gold's history in May?
#
# 5. Good time to invest in gold?"
#
#
# First 5 articles containing 'silver':
# 1. Every post and comment you have ever made was related to persuading people to buy silver.
#
# 2. Originally posted by kervio: ↑ I think the update said median age of the first set of patients was around mid 50s and median age of the later set of patients was around 69, so they would have only had to have put the inclusion criteria in half way through the trial when the evidence was emerging that age was a huge factor in deaths in order to have a successful trial. This is the big "what if" that might have sent the SP to $10, FDA approval, lives saved etc.We can give them a pass on not knowing that up front for sure because of the speed in which the trial moved forwards on, but I think some reactivity would have saved the day here once more was known about covid (in the same way that we found out about comorbidities leading to higher rates of death).I disagree with this: "This disease has been totally wacky in respect of different age cohorts, and no one has or has had any idea what is going to happen to any given age group once confronted with the disease or results/impact. COVID has everyone flummoxed." until the Brazil variant turned everything on its head (which happened after the trial) there was lots of clear evidence in white papers about the effect of age on covid mortality. The inclusion criteria is there to stop random chance from derailing your study, so if they had say 10 or so 80yo patients that were enrolled and bound to die no matter what it lessons the effect of your treatment on a saveable demographic within your cohort. I agree with your excitement on what the results though, and I think this therapy has some big potential to show effect and get approval in a confirmatory trial with appropriate design. It's better than I expected the results to be. Expand Hey,@kervio. Good points on age effect. I guess I was thinking more broadly, say in respect of MIS-C in kids, under-50s getting blood clots with the Astra Zeneca and J&J vaccines, etc. A lot about COVID has been very unpredictable.As well, we don't know what conversations, if any, were had between MSB, NIH, the FDA and the DSMB. Clearly, someone made the decision not to modify the inclusion criteria and continue the trial, opting to halt it, instead. Most likely NOT MSB's choice, and I doubt they would have been given enough information by the DSMB to allow them to make this call on their own. I am clearly not qualified to speak on the issue, of course!LeftYahoo had a good point about the silver lining here, though - we get the full trial results that much earlier, with it having been halted. Fingers crossed the NIH, the FDA and Novartis are as excited about these amazing results as we are!
#
# 3. 14 Homegrown labels that are donating their profits to Covid-19 relief. In times of turmoil, fashion can seem frivolous. But on closer introspection there is a whole ecosystem that survives and thrives on it. If shopping is your therapy or you are simply filling a requirement, we jot down a few do-good homegrown brands that are donating their profits to Covid-19 relief. The second wave of Covid-19 in India is filled with the feeling of gloom and doom. The only speck of positivity in this space is power of the people. Whether it’s the frontline workers, the caregivers or the social media influencers collecting resources – there has been a mass movement of people stepping up to help those in need. In times of need, homegrown brands are reaching out to do their bit and help the cause. With brands dedicating their profits to organisations that are providing relief to those affected by the Covid-19 crisis , it’s not simply a necklace, a dress or a face mask you’re purchasing.  Juicy Chemistry      The ECOCERT certified organic beauty label is contributing all the proceeds from their Mother’s Day sale to support the relief efforts. Shop here to do your part.   Olio      A special shout out to this homegrown jewellery label run by two women entrepreneurs, Aashna Singh and Sneha Saksena who decided to donate 100% proceeds from their sales to organisations that are helping fight Covid-19 on the ground. While the brand had planned to host a 3 day sale, with a target of raising two lakh rupees, they superseded this mark by raising Rs 12,40,974 in a single day making them end the donation drive due to shortage of staff and being a small business.   Studio Metallurgy       If you’re looking for statement jewellery, then Studio Metallurgy gold-plated pieces are a worthy investment and contribution. The brand is  donating 100% of the sale proceeds of their curated top 10 bestsellers for Covid-19 relief.    AA Living      Feel free to use the evil eye collection from AA Living as a talisman to ward off the problems troubling the country. If you do, 100% of the proceeds will get donated to Covid-19 relief charities in India,  through the entire month of May.   YAM      This homegrown label is running a sample sale on their Instagram page filled with beautifully crafted dresses, shirts and so on. With a total of 10 garments being put up daily, the brand is using the proceeds to support Hemkunt Organisation in Gurgaon that is providing oxygen cylinders to Covid-19 patients.    Rattle & Co.      Clothing for young ones almost comes under an essential buy, and that’s why we are leaning towards the beautiful pieces at Rattle & Co. Their bestsellers are on discount and 50% proceeds are going for a noble cause.  Itraake      If you’re looking for comfortable and sustainable handloom items for summer then head to Itraake. The brand is donating all sale proceeds to Hemkunt Foundation till May 2, 2020.    Love Letter      Gold vermeil, sterling silver and recycled plastic – the jewellery at Love Letter is unique in all its form and can serve as a good reminder of happier days ahead. They are also donating all sale proceeds from April 20 to May 20, 2020 to Hemkunt Foundation.   JODI      The homegrown brand known for its beautiful dresses wants to amplify and offer help to those in need all over the country. They are offering a 20% discount on all orders with the code JODICARES plus all proceeds going to Hemkunt Foundation for the next three days.     Megha Bansal      Showing gratitude for the invisible warriors who are helping us battle the pandemic, Megha Bansal label is donating 100% of the proceeds to Hemkunt Foundation, Mission Oxygen, Khaana Chahiye and Make Luv Not Scars. Pick from the Covid-19 relief section on our website, also they promise to share all the necessary information regarding the transfer of your funds.  Sher Bache      From a kids brand to creating beautifully made clothes for adults too, Sher Bache has come a long way. The bra ...
#
# 4. $CLSH CLS Holdings USA, Inc. Welcomes New Board Member, Mr. Ross Silver https://t.co/lKEKbX9P5T  #LasVagas… https://t.co/0HZQNRobEo
#
# 5. #Newsmaker: Cassandra Wingrove heading up sales at Mickey Llew's Australian office. Performance marketing and SEO agency Mickey Llew recently appointed Cassandra Wingrove to lead growth and development at its Australian office. She has been tasked with developing and coordinating growth opportunities to reach the company’s sales objectives of $1.2 AUD (R14m). She will also provide broad operational day-to-day support to the team as the Australian offering and services were previously managed from the Johannesburg head office. Wingrove has a BA Degree in Communications and an Honours in Psychology from the University of Johannesburg and brings a wealth of experience gained from the digital marketing sector. Some of her core capabilities include forecasting the budgeting cycle, managing the financial reporting, developing online communication strategies and providing business intelligence. She says she’s excited to be joining the agency at such a crucial and dynamic period in its growth journey, with the Australian expansion. “I am thrilled to be joining Mickey Llew at such an exciting time as the business expands into Australia. It is also a very interesting time for digital with more opportunities than ever before. Will you be based in South Africa or Australia? I am based in Australia and have lived in Sydney for the past five years. What is your job title and what does your role entail exactly? Head of Sales. I am focusing on building the foundations of the Australian Office, through new client acquisition and also managing the day-to-day operations. We do also have plans to grow out the Australian team. How you plan to navigate the Australian office through these unusual times? These are challenging times around the world, however, a silver lining is that it has allowed certain industries to flourish, such as e-commerce. There have been more opportunities for agencies like Mickey Llew as SEO has never been so important, especially with travel being restricted. It has pushed consumers to discover local businesses nearby. What excites you most about the agency and the Australian office in part? The opportunity at hand. Mickey Llew has built a reputable name for themselves in the South African market by forming strong relationships with their clients, delivering bespoke services and achieving bankable results. This has laid a strong foundation to scale the business fairly quickly and will allow us to build out an Australian-based team. What are you most looking forward to or enjoying thus far? I am enjoying networking with other agencies and business owners. Tell us more about your background/experience and how this has equipped you for the role. I have been in the tech industry for the past seven years. Most of my time was spent at a global media intelligence company, which allowed me to be exposed to running new business processes across IMEA. I was then transferred to the company’s office based in Australia, where I worked across their key account clients. This gave me exposure to many Australian businesses across different industries. I have also been involved in a sideline business of selling on Amazon marketplace in the USA, which has given me a good understanding of some of the foundations that make up SEO, such as keyword research, product listing and running effective campaigns. What do you love most about your career? I love working in the tech industry because I believe in progress. People inevitably use technology to improve lives and help others. We spread knowledge, make tasks easier and make systems more efficient. Also, the industry is fast-paced and always evolving, meaning that there is always something new to learn. What’s at the top of your to-do list? To start building out our local partnerships with other agencies and businesses. What are you currently reading/watching/listening to? I love listening to podcasts whilst I exercise. As a mom of two little boys, the ability to multitask is an essential per ...

# %%
# The problem is that simply checking for the string "gold" or "silver" also counts these strings when they are mentioned in a non-financial context (e.g., gold medal). This is called false positives. spaCy recognizes an article as finance-related, when in reality it's not. It's, for example, sport-related. But this happened because of the simplistic approach we have chosen. Simply looking for the strings produces a lot of false positives.

# %%
# We need to do NER, not checking for the strings. We will use spaCy for NER.

# %%
# Define a function for matching entities in an article
def entity_matcher(article):
    # Process the article using spaCy
    doc = nlp(article)

    # Check if "gold" or "silver" is present as a recognized entity with the label "COMMODITY"
    gold_present = any(token.ent_type_ == "COMMODITY" and token.text.lower() == "gold" for token in doc)
    silver_present = any(token.ent_type_ == "COMMODITY" and token.text.lower() == "silver" for token in doc)

    return gold_present, silver_present

# Initialize counters for the number of articles containing 'gold' and 'silver' as commodities
gold_count = 0
silver_count = 0

# Loop through each article in the list of articles
for article in articles:
    # Call the entity_matcher function to check for 'gold' and 'silver' in the current article
    gold_present, silver_present = entity_matcher(article)

    # Increment the counters if 'gold' or 'silver' is present in the current article
    if gold_present:
        gold_count += 1
    if silver_present:
        silver_count += 1

# Display the results
print("Number of articles containing 'gold' as a commodity:", gold_count)
print("Number of articles containing 'silver' as a commodity:", silver_count)
# Out:
# Number of articles containing 'gold' as a commodity: 0
# Number of articles containing 'silver' as a commodity: 0

# %%
# Something is wrong because spaCy didn't find any articles containing "gold" or "silver" as a commodity.

# %%
# Let's print all entities that spaCy finds in articles.

# %%
def print_entities(article):
    # Process the article using spaCy
    doc = nlp(article)

    # Print all recognized entities
    entities = [f"{ent.text} ({ent.label_})" for ent in doc.ents]
    print(f"Entities in the article: {', '.join(entities)}")

# Iterate through the first 3 articles and print entities
for i, article in enumerate(articles[:3], start=1):
    # Print header for each article
    print(f"\nEntities in Article {i}:\n")
    
    # Call the function to print entities for the current article
    print_entities(article)
    
    # Print separator between articles
    print("-----\n")
# Out:
# Entities in Article 1:
#
# Entities in the article: Tenrec (GPE)
# -----
#
#
# Entities in Article 2:
#
# Entities in the article: Tokyo (GPE), Sampson (PERSON), Aust (GPE), Shooter Dane Sampson (ORG), third (ORDINAL), Olympics (EVENT), 50m (QUANTITY), South Australia (GPE), Sampson (PERSON), 462 (CARDINAL), three (CARDINAL), Sampson (ORG), 460.7 (CARDINAL), last month's (DATE), Wingfield (PERSON), Italy (GPE), Niccolo Campriani (PERSON), 458.8 (CARDINAL), Poland (GPE), Tomasz Bartnik (PERSON), 460.4 (CARDINAL), 2016 (DATE), Olympics (EVENT), 2018 (DATE), Sampson (PERSON), 2012 (DATE), 2016 (DATE), Olympics (EVENT), Tokyo (GPE), Sampson (PERSON), Australia (GPE), 2021 (DATE), Olympics (EVENT), pre-Games (EVENT), July 4-19 (DATE), Tokyo (GPE)
# -----
#
#
# Entities in Article 3:
#
# Entities in the article: 33 (CARDINAL), 688 (CARDINAL), MCB (ORG), a National Park (FAC), One (CARDINAL)
# -----

# %%
# It looks like spaCy doesn't have the label "COMMODITY" or anything similar defined by default. There were multiple organizations, products, people, etc. found, but not commodities.

# %%
# We can run the following code to get all the labels spaCy has defined by default.

# %%
# Retrieve the list of named entity labels used by the NER pipeline in the spaCy processing pipeline
nlp.get_pipe('ner').labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
# We can confirm that there's no "COMMODITY" label or anything similar.

# %%
# Let's add the "COMMODITY" label to spaCy and test a simple text to see if spaCy now recognizes gold as an entity under the "COMMODITY" label.

# %%
# Import spaCy and the EntityRuler class
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create an instance of the EntityRuler
ruler = EntityRuler(nlp)

# Define patterns for the EntityRuler
patterns = [
    {"label": "COMMODITY", "pattern": "gold"}
]

# Add the EntityRuler to the spaCy pipeline
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Test the sentence
text = "Good time to buy gold?"
doc = nlp(text)

# Print recognized entities
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# gold COMMODITY

# %%
# Success! "Gold" was recognized as an entity under the label "COMMODITY" by spaCy. Now we want to extract full articles if, in any sentence inside the article, "gold" or "silver" are found as commodities.

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create an instance of the EntityRuler
ruler = EntityRuler(nlp)

# Define patterns for the new entities
patterns = [
    {"label": "COMMODITY", "pattern": "gold"},
    {"label": "COMMODITY", "pattern": "silver"}
]

# Add the EntityRuler to the spaCy pipeline
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Read articles from file
with open("sample.txt", "r", encoding="utf-8") as file:
    articles = file.readlines()

# Counter for the number of articles containing "COMMODITY"
commodity_article_count = 0

# Print the first 4 articles containing the entity "COMMODITY"
print("First 4 articles containing 'COMMODITY':")
for i, article in enumerate(articles, start=1):
    doc = nlp(article)
    
    # Extract entities with the label "COMMODITY"
    commodity_entities = [entity.text for entity in doc.ents if entity.label_ == "COMMODITY"]
    
    # Check if there are any COMMODITY entities in the article
    if commodity_entities:
        # Increment the count of articles containing "COMMODITY"
        commodity_article_count += 1

        # Print the actual article number and the content
        print(f"{commodity_article_count}. {article.strip()} \n")

        # Check if 4 articles with "COMMODITY" entities have been printed
        if commodity_article_count == 4:
            break
# Out:
# First 4 articles containing 'COMMODITY':
# 1. Tokyo-bound Sampson sets Aust rifle record. Shooter Dane Sampson has struck career-best form as he builds towards a third Olympics, setting a national record while winning the 50m rifle event at the South Australia championships. Sampson registered a score of 462 points to claim gold in the three positions event. The performance bettered Sampson's own national record of 460.7 points, which he achieved at last month's Wingfield grand prix. The score was also notably higher than what Italy's Niccolo Campriani (458.8) and Poland's Tomasz Bartnik (460.4) produced to win gold at the 2016 Olympics and 2018 world championships respectively. "It's good to be shooting PBs at this stage. It was a world-class finals score," Sampson said, having previously competed at the 2012 and 2016 Olympics. "You are unlikely to lose many competitions with that score. "I definitely feel that I am getting better and better and I am tracking well for Tokyo." Sampson and other members of Australia's shooting team for the 2021 Olympics are set to come together for a pre-Games camp on July 4-19. The camp is intended to mimic the biosecurity bubble and strict protocols that await in Tokyo.
#
# 2. Originally posted by cordingup ↑ I see very interesting says the drill hole 33 now at 688 m so thats 88 m past the planned depth should mean they are still in mineralisation? Also i see in the tenements list those other permits around the MCB area they are still pursuing under appeal i guess the appeal is regards large sections of those falling into a National Park ??? One of those tenements from my reckoning hosts a copper gold resource another has a copper prospect. Expand That does sound promising. Gap up on open
#
# 3. "US 500 Futures Discussions. Hey guys what is gold's history in May?
#
# 4. Good time to invest in gold?"

# %%
# As we can see, there are a lot of false positives (e.g., "Sampson registered a score of 462 points to claim gold in the three positions event."). This is a sentence where "gold" is not mentioned in a financial context, but spaCy treats this sentence as if it were.

# %%
# Let's try to define patterns for a new entity called "COMMODITY" in more detail. We will add two more patterns using "IN". It stands for "inclusion". It is used as part of the pattern to specify that the token's lowercase text should be in a list of possible values. This pattern is looking for a lowercase token where the text is either "price", "market", or "commodity". It allows flexibility to match any of the specified words. The "IN" operator is used to define this set of possible values for the token.

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create EntityRuler instance
ruler = EntityRuler(nlp)

# Define patterns for the new entities
patterns = [
    {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}, {"LOWER": {"IN": ["price", "market", "commodity"]}}]}, # Added
    {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}, {"LOWER": {"IN": ["price", "market", "commodity"]}}]}, # Added
]

# Add patterns to the EntityRuler
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Read articles from file
with open("sample.txt", "r", encoding="utf-8") as file:
    articles = file.readlines()

# Initialize counter
article_count = 0

# Iterate through all articles
for i, article in enumerate(articles, start=1):
    doc = nlp(article)
    
    # Iterate through sentences in the article and print those containing "COMMODITY"
    for sent in doc.sents:
        sent_entities = [entity.text for entity in sent.ents if entity.label_ == "COMMODITY"]
        
        if sent_entities:
            article_count += 1
            print(f"Article {i}, Sentence {sent.start}:")
            print(sent.text)
            print("-----\n")

# Print the total number of articles found
print(f"Articles found: {article_count}")
# Out:
# Article 1, Sentence 0:
# @fansoniclove Gold the Tenrec
#
# -----
#
# Article 2, Sentence 43:
# Sampson registered a score of 462 points to claim gold in the three positions event.
# -----
#
# Article 2, Sentence 82:
# The score was also notably higher than what Italy's Niccolo Campriani (458.8) and Poland's Tomasz Bartnik (460.4) produced to win gold at the 2016 Olympics and 2018 world championships respectively.
# -----
#
# Article 3, Sentence 73:
# One of those tenements from my reckoning hosts a copper gold resource another has a copper prospect.
# -----
#
# Article 4, Sentence 6:
# Hey guys what is gold's history in May?
#
# -----
#
# Article 5, Sentence 0:
# Good time to invest in gold?"
#
# -----
#
# Article 6, Sentence 0:
# Gold edges lower as firmer US yields pinch appeal https://t.co/P0HPkmXvBZ
#
# -----
#
# Article 7, Sentence 354:
# In both transactions, there was a critical decision about the heritage of the Ghanaian young person; because this gold resource, which is a Ghanaian resource was being treated in a certain way, was it being treated in the right way to guarantee the future of the young people that today Sam Jonah is concerned about?
# -----
#
# Article 13, Sentence 8:
# Trade range 1.40 -1.80  Gold falls all eyes on FED rate decision https://t.co/BgU5kmqPX2
#
# -----
#
# Article 14, Sentence 4:
# I read somewhere that ounces of gold per person were almost constant in history, but not the money...  all previous reserve currencies failed, probably it is dollar turn with Modern Monetary theory at WH
#
# -----
#
# Article 15, Sentence 0:
# @chidinmaekile Adekunle Gold it will go along way in my studies and that of my siblings🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏… https://t.co/JtY9VgSARn
#
# -----
#
# Article 16, Sentence 0:
# Gold Dust Box, 19th-20th century https://t.co/TWBhpLY77c #africanart #brooklynmuseum https://t.co/tlsFXJZV1Y
#
# -----
#
# Article 17, Sentence 43:
# Gold steps back from intraday high while flashing $1,772 as a quote amid Friday’s Asian session.
# -----
#
# Article 19, Sentence 173:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 20, Sentence 0:
# RT @RoKhanna: #Bitcoin uses energy like cars, gold, &amp; finance.
# -----
#
# Article 21, Sentence 0:
# Re: Can Crypto be more valuable than gold?.
# -----
#
# Article 21, Sentence 11:
# BTC is more valuable than Gold right now and many crypto projects will join soon, crypto is a work in progress and we are getting nearer to mass adoption finally, Gold is still a good investment choice but the future is just more into technology this days
#
# -----
#
# Article 22, Sentence 0:
# Study the table to answer question 4 &amp; 5   Sexoverlove   Adekunle Gold SWBtheAlbum https://t.co/cFb6cgX2M3
#
# -----
#
# Article 23, Sentence 0:
# Every post and comment you have ever made was related to persuading people to buy silver.
#
# -----
#
# Article 24, Sentence 0:
# Gold comments on April 30, 2021: #XAUUSD #PREMIUM #comextips2021 #goldtips #comexsignals #signals https://t.co/ebw20MTytG
#
# -----
#
# Article 25, Sentence 13:
# Metal: Gold filled  .
# -----
#
# Article 26, Sentence 42:
# One of my other gold/copper plays has a Nil desperandum target too.
# -----
#
# Article 27, Sentence 0:
# Some very old gold.
# -----
#
# Article 27, Sentence 5:
# POLICIA NACIONAL investigators traced to Calpe a 716 gold coin that was offered for sale online.
# -----
#
# Article 27, Sentence 22:
# Only 24 of the gold dinars that were minted in Cordoba and  amongst the first in circulation following the Moorish conquest of Spain have ever been located.
# -----
#
# Article 30, Sentence 3212:
# In CIS, sales declined, affected by sluggish demand for mining equipment in coal mines and depreciation of the Russian ruble, while demand was steady in gold mines and that for construction equipment was on a recovery track in infrastructure development and energy-related sectors.
# -----
#
# Article 30, Sentence 3886:
# Furthermore, Komatsu projects that demand for mining equipment will remain steady in iron ore, copper, and gold mines, while it will enter a recovery track in coal mines.
# -----
#
# Article 32, Sentence 0:
# $AITX the bears are retards just leave them be Us bulls know that we’re holding gold.
# -----
#
# Article 33, Sentence 8:
# Gold foil, treated paper, sharpie, cardboard https://t.co/qOZlHkuxrT
#
# -----
#
# Article 35, Sentence 0:
# @ApplWatcher Gold standard?
# -----
#
# Article 36, Sentence 0:
# RT @met_greekroman: Gold earring with head of an antelope, 4th–3rd century B.C. https://t.co/hMRLU72HaW #greekromanart #metmuseum https://t…
#
# -----
#
# Article 37, Sentence 472:
# I am clearly not qualified to speak on the issue, of course!LeftYahoo had a good point about the silver lining here, though - we get the full trial results that much earlier, with it having been halted.
# -----
#
# Article 38, Sentence 0:
# Here's a custom 14k yellow gold design for oval fans!
# -----
#
# Article 47, Sentence 9:
# % and ameros fag says yields support gold rise
#
# -----
#
# Article 48, Sentence 0:
# https://t.co/GcrC4xmcJF 18K White Gold Cubic Zirconia Round Necklace &amp; Earrings Wedding Set  £9.99!
# -----
#
# Article 49, Sentence 0:
# Gold price trading in neutral territory following rising inflation, U.S. personal income grows 21.1% in March… https://t.co/bvJEdowf6g
#
# -----
#
# Article 50, Sentence 0:
# Gold Price Today April 30: Gold Rate Continues To Fall, Check City-Wise Price List https://t.co/HGRF8zgSS9
#
# -----
#
# Article 54, Sentence 318:
# Studio Metallurgy       If you’re looking for statement jewellery, then Studio Metallurgy gold-plated pieces are a worthy investment and contribution.
# -----
#
# Article 54, Sentence 560:
# Love Letter      Gold vermeil, sterling silver and recycled plastic – the jewellery at Love Letter is unique in all its form and can serve as a good reminder of happier days ahead.
# -----
#
# Article 55, Sentence 0:
# Three National Honorary Gold Medal Winners Internal / External Relations and Information Division ‌ Deputy Director… https://t.co/aRYNYbRhj0
#
# -----
#
# Article 56, Sentence 339:
# The latest 10-year US bond yield was reported at 1.645%; spot gold was reported at US$1,770.87 per ounce.
# -----
#
# Article 58, Sentence 0:
# Solid U.S. Values, Bond Yields, and GDP Put Pressure on Gold   https://t.co/QkUUeVPsGI
# -----
#
# Article 61, Sentence 58:
# In the Bitcoin White Paper written by Satoshi, there is one piece of the puzzle left out: references to Bit Gold.
#
# -----
#
# Article 70, Sentence 13:
# Ancient wisdom valuable like gifts of Gold I embark on life, my path is a…
#
# -----
#
# Article 74, Sentence 0:
# Gold £10,000 coin weighing 22lb produced at Royal Mint in Llantrisant - https://t.co/2aR6fnn0cM  The 8in-wide (20cm… https://t.co/7skWbHoa6G
#
# -----
#
# Article 83, Sentence 0:
# In search of                       We lost  Gold                                    diamond https://t.co/Nc4lNUUeiW
#
# -----
#
# Article 84, Sentence 0:
# We have a nice selection of Nahaia 24Kt Gold Skincare bundle offers 😍 for you.
# -----
#
# Article 86, Sentence 0:
# "mine for gold: make something and get real reward.
#
# -----
#
# Article 90, Sentence 0:
# "$AMC Remember the Smaug from Lord of the rings and how he hoards Gold?
# -----
#
# Article 94, Sentence 456:
# If a company owns one mining licence and literally strikes gold, its return on capital could be huge.
# -----
#
# Article 95, Sentence 306:
# These are challenging times around the world, however, a silver lining is that it has allowed certain industries to flourish, such as e-commerce.
# -----
#
# Article 96, Sentence 11:
# Jessica Villarubin took a seat on the last Gold Chair.
# -----
#
# Article 97, Sentence 0:
# RT @lambardferagamo: BNY Mellon fund complains it should have bought #Bitcoin, not #gold
#
# -----
#
# Article 100, Sentence 0:
# What's the difference between Bitcoin cash and Bitcoin gold?
# -----
#
# Article 102, Sentence 0:
# $AITX Long term gold mine.
# -----
#
# Article 106, Sentence 0:
# Gold Glitter Monogram Poker Chip Casino Wedding Napkins https://t.co/qZ6gJf7rb4 via @zazzle
#
# -----
#
# Article 108, Sentence 0:
# Gold futures eke out gain on volatile day, silver near Rs 67,550/kg: What analysts say - Domestic gold prices seesa… https://t.co/w6qkrpNcOA
#
# -----
#
# Article 110, Sentence 0:
# Hit🔥🔥 Laycon Adekunle Gold Burna boy @itsLaycon  @adekunleGOLD  @burnaboy  Now let listen to the songs #laycon #SWBAlbum
#
# -----
#
# Article 112, Sentence 0:
# RT @Trans_Ticketing: We're delighted to welcome @Vix_Technology as Gold Sponsor of the Transport Ticketing Digital Summit!
# -----
#
# Article 115, Sentence 0:
# JPOW is lucky he is a silver fox with lots of tools, wish he would return my calls 😕"
#
# -----
#
# Article 116, Sentence 0:
# RT @CoinBoards: BNY Mellon fund laments it should have bought Bitcoin, not gold https://t.co/fEAjqLWmVG
#
# -----
#
# Article 117, Sentence 0:
# Gold Trend Analysis Update.
# -----
#
# Article 117, Sentence 5:
# Gold has a chance to buy when it drops once more by the daily resistance key level and then hits a low in the beginning of next week.
# -----
#
# Article 117, Sentence 51:
# Gold will rise above 1900 in the short term.
#
# -----
#
# Article 125, Sentence 3:
# does he shit literal gold?
#
# -----
#
# Article 127, Sentence 0:
# Gold | $XAUUSD | $XAU $USD
# -----
#
# Article 127, Sentence 10:
# 📝 Gold: the balance of the week is dynamically down.
# -----
#
# Article 131, Sentence 0:
# Gold Trades Marginally Lower, Silver Edges Higher On MCX  https://t.co/4Im5WckTtN...
# -----
#
# Article 132, Sentence 9:
# That is all true except:Humanity has spent centuries trying to prove that alchemy ( turning metal to gold) is not possible.
# -----
#
# Article 133, Sentence 0:
# $PRU $RMS $NIC $WGX $BGL $PNR Gold Digger: Australia’s big gold miners are getting bigger, and investors should rea… https://t.co/FzT8ReHUff
#
# -----
#
# Article 135, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Sterling Silver &amp; 14K Gold Ring Thailand Size 6.…
# -----
#
# Article 136, Sentence 0:
# fxmimior Bohemian Dainty Gold Big Butterfly Earrings Big Dainty Gold Drop Earrings Statement Charm Earring Body Jew… https://t.co/QRWgZGyoX7
#
# -----
#
# Article 137, Sentence 0:
# Playing now: Fool's Gold - Sofia Carson 🎧 Listen live at https://t.co/keYSgwmSlo 🏳️‍🌈 📻
#
# -----
#
# Article 138, Sentence 0:
# $AABB believe in the vision of a company that wants to change the world with gold backing.
# -----
#
# Article 140, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 142, Sentence 449:
# Gold bullion volumes increased more than 100% year over year and were 982.8 thousand ounces (2019 – 483.0 thousand ounces) while silver bullion volumes were 29.5 million ounces (2019 – 22.8 million ounces).
# -----
#
# Article 144, Sentence 10:
# What’s your problem gold?
# -----
#
# Article 146, Sentence 0:
# RT @SaskOrganics: A big thank you to Sunrise Foods International for their Gold Sponsorship of the Organic Grain Markets Webinar on April 3…
#
# -----
#
# Article 147, Sentence 0:
# Notice To Disregard — GSB Gold Standard Banking Corporation AG.
# -----
#
# Article 147, Sentence 11:
# April 30,  2021  Latest Update:  April 30,  2021 1:45 pm   Less than a minute     HAMBURG, Germany, April 30 (Bernama-GLOBE NEWSWIRE) —  We are advised by GSB GOLD STANDARD BANKING CORPORATION AG that journalists and other readers should disregard the news release, “GSB Group doubts in gold reserves of Karatbars and the V999 Coin as well as the existence of the Osint Group” issued April 28, 2021, over GlobeNewswire.
# -----
#
# Article 149, Sentence 1312:
# Two weeks ago, minister Rachel Maclean accused the council of wearing “gold-tinted lenses” and said a “blank cheque” would not be forthcoming.
# -----
#
# Article 162, Sentence 11:
# Gold doesn't rust 🤣 dogecoin is snake oil.
#
# -----
#
# Article 164, Sentence 376:
# “Over the years, we have excellent performances at the JCDC festival, winning many gold medals as well as silver medals in dance, music and speech,” she said.
# -----
#
# Article 165, Sentence 0:
# How to Find Value of your Gold Piece https://t.co/kWgQxeReOQ
#
# -----
#
# Article 166, Sentence 0:
# RT @_mary_stylinson: @dzuliagrape Night changes vs Fools Gold   I vote #Louies for #BestFanArmy at the #iHeartAwards︎
#
# -----
#
# Article 167, Sentence 0:
# Four Gold Coast teens charged after dangerous joyride in stolen 4WD https://t.co/8dZd0ARkAV #GoldCoastNews https://t.co/9qPAyXu2sw
#
# -----
#
# Article 171, Sentence 26:
# Favorable gold, copper prices that drove ear…
#
# -----
#
# Article 175, Sentence 0:
# Hall Of Fame trainer to set-up stables at the Gold Coast 🌊👇 https://t.co/O5Jrboto7B
#
# -----
#
# Article 178, Sentence 12:
# Gold standard of journalism... anyone?
#
# -----
#
# Article 180, Sentence 12:
# https://www.theaustralian.com.au/business/dgo-gold-aiming-to-strike-a-balance-in-gold-exploration/news-story/231d9ce048bfd7d7f87545741008db15DGO Gold aiming to strike a balance in gold explorationDGO Gold is hoping it has created a strategic investment model that will reinvigorate gold exploration in Australia.
# -----
#
# Article 180, Sentence 40:
# Picture: BloombergDAMON KITNEYVICTORIAN BUSINESS EDITOR6:42PM APRIL 25, 2021Melbourne investment banker Bruce Parncutt calls his latest plaything a “gold discovery company”.
# -----
#
# Article 180, Sentence 64:
# Neither an explorer nor a miner, the ASX-listed DGO Gold — of which Mr Parncutt has been an executive director for the past year — is looking to carve out a unique niche in the Australian gold sector.
# -----
#
# Article 180, Sentence 106:
# Its game plan is to make strategic equity investments in West Australian brownfield gold discoveries, bankroll themwith additional capital and combine them with its own pursuit of largely-ignored exploration opportunities.
# -----
#
# Article 180, Sentence 140:
# Mr Parncutt said he hopes DGO has created a model that can reinvigorate gold exploration in Australia.
# -----
#
# Article 180, Sentence 284:
# As Joseph Gutnick’s exploration director in the late 1980s and early 1990s, Mr Eshuys led the teams that discovered the Plutonic, Bronzewing and Jundee gold deposits and the Cawse nickel deposit.
# -----
#
# Article 180, Sentence 340:
# He is now DGO Gold’s executive chairman and is working closely with Mr Parncutt — who has been on the board since 2018 — and DGO’s management team to develop two sizeable WA gold resources and to explore for more.
# -----
#
# Article 180, Sentence 458:
# Gold directors Ed Eshuys and Bruce Parncutt.
# -----
#
# Article 180, Sentence 466:
# DGO Gold initially evaluated 100 gold explorers and their projects.
# -----
#
# Article 180, Sentence 477:
# Ten ASX juniors made the shortlist before DGO narrowed it down to two, taking strategic stakes in booming Pilbara gold explorer De Grey Mining and Leonora
# -----
#
# Article 180, Sentence 504:
# gold explorer NTM Gold.
# -----
#
# Article 180, Sentence 663:
# ”The strategy has seen DGO Gold shares soar from just 17c four years ago, and $1.70 last year when Mr Parncutt became an executive, to close on Friday at $3.63.They soared over $4 in September last year on the back of the coronavirus-fuelled surge in the gold price, which saw it spike to $US2056 per ounce last August.
# -----
#
# Article 180, Sentence 731:
# While gold prices have trended lower since the start of 2021 amid rising US Treasury yields and an increasingly positive outlook for the global economic recovery, the DGO share price has held up.
# -----
#
# Article 180, Sentence 766:
# DGO now owns 16 per cent of De Grey, which is drilling out a significant Pilbara gold discovery.
# -----
#
# Article 180, Sentence 842:
# Following the merger late last year of NTM Gold with Dacian Gold, DGO will now emerge with a 10 per cent stake in Dacian.
# -----
#
# Article 183, Sentence 0:
# Gold edges lower as firmer US yields pinch appeal https://t.co/h6yCfptLqY
#
# -----
#
# Article 184, Sentence 4:
# ani time blast gold
#
# -----
#
# Article 185, Sentence 0:
# Global gold demand, first quarter near low level for the first time in 13 years Investor sales.
# -----
#
# Article 185, Sentence 25:
# --Global gold demand in the first quarter of this year has remained near its lowest level since 2008, according to a quarterly report released by the World Gold Council (WGC), an international gold research institute.
# -----
#
# Article 185, Sentence 85:
# Last year, as the spread of the new coronavirus hit the global economy, investors were increasingly buying gold as a safe haven.
# -----
#
# Article 185, Sentence 110:
# At the same time, lockdowns to curb the spread of infection have slowed sales of gold jewelery, gold nuggets and gold coins in China and India, which are normally the two biggest consumers.
# -----
#
# Article 185, Sentence 170:
# According to the WGC, global gold demand from January to March this year was 815.7 tons, a slight increase from 813.7 tons in the previous quarter.
# -----
#
# Article 185, Sentence 230:
# On the other hand, exchange-traded fund (ETF) gold holdings fell by 177.9 tons, the largest decline since the fourth quarter of 2013.
# -----
#
# Article 185, Sentence 259:
# Due to the sale by ETF, the gold price fell from the record high of 1 ounce = $ 2072.50 in August last year to around $ 1,700 in March.
# -----
#
# Article 185, Sentence 303:
# In April, ETF sales slowed sharply and gold prices picked up towards $ 1800.
# -----
#
# Article 185, Sentence 319:
# WGC analyst Christian Gopaul said consumers and investors&#39; demand for gold this year is likely to remain resilient, albeit below its recent peak.
# -----
#
# Article 185, Sentence 345:
# Gold purchased by the central bank in the first quarter was 95.5 tonnes, the highest level since the second quarter of last year.
# -----
#
# Article 186, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 188, Sentence 0:
# @AskAmex Gold delta sky miles .
# -----
#
# Article 196, Sentence 0:
# @GlobalBTSVoting Stay Gold  BTSARMY FIGHT
# -----
#
# Article 198, Sentence 15:
# Meanwhile, spot gold was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 198, Sentence 300:
# Meanwhile, spot gold was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 198, Sentence 317:
# U.S. gold futures were steady at $1,769.00.
# -----
#
# Article 198, Sentence 360:
# Silver fell 0.5% to $25.96 per ounce, though was poised for an over 6% monthly gain - its biggest since last December.
# -----
#
# Article 199, Sentence 12:
# Testing 200MA Support:  1⃣ Mag Silver, $MAG 2⃣ Alexco Resources, $AXU 3⃣ Southern Silver, $S…
#
# -----
#
# Article 200, Sentence 13:
# Silver Gold or Platinum.
# -----
#
# Article 201, Sentence 244:
# Tranquil Green, Frost Silver, and Deep sea for fantastic guys.
# -----
#
# Article 204, Sentence 0:
# 👉 $209.99 👈 Apple iPad Air 2 16 GB Gold Renewed @iotcybersec24   #Apple #iPad #Air #2 #16 #GB #Gold #Renewed… https://t.co/DiwpGVADcw
#
# -----
#
# Article 205, Sentence 0:
# @musangpandan02 @geenocure @DocumentingBafe @adepianpratama @Bafeio Gold n Diamond Goooooo
#
# -----
#
# Article 206, Sentence 0:
# RT @NationOnlineMw: The Reserve Bank of Malawi (RBM) is set to start buying gold in a move that may transform the country’s mining industry…
#
# -----
#
# Article 209, Sentence 0:
# Gold Price Today: Yellow metal corrects as bond yields rise ahead of Fed meeting https://t.co/zlxjyFjL3g https://t.co/2FDPSqHyTh
#
# -----
#
# Article 213, Sentence 5:
# Gold c: I appreciate you and your will to fight is what keeps me going!
# -----
#
# Article 215, Sentence 0:
# China&#39;s gold production in the first quarter shrinks by 10% and consumption is 94%.
# -----
#
# Article 215, Sentence 17:
# The China Gold Association announced that the domestic raw material gold production in the first quarter of this year was 74.44 tons, a year-on-year decrease of 9.92%.
# -----
#
# Article 215, Sentence 51:
# Among them, China National Gold, Shandong Gold, Zijin Mining, Shandong Zhaojin and other large gold conglomerates produced 30.78 tons of mineral gold, accounting for the proportion of the country.
# -----
#
# Article 215, Sentence 91:
# According to the association, the actual consumption of gold in the country during the period was 288.2 tons, an increase of 93.9% year-on-year.
# -----
#
# Article 215, Sentence 122:
# Among them, gold jewellery was 169.18 tons, an increase of 83.81%.
# -----
#
# Article 215, Sentence 137:
# Based on the low base caused by the outbreak in the same period last year, and the results of China&#39;s overall epidemic prevention and control and economic and social development gradually appearing, the gold consumption in the first quarter has returned to the level of the same period in 2019.
# -----
#
# Article 215, Sentence 190:
# The scale of domestic gold ETFs continued to grow in the first quarter, with a total increase of 11.5 tons.
# -----
#
# Article 215, Sentence 212:
# As of the end of March, domestic gold ETF holdings were about 72.4 tons.
# -----
#
# Article 215, Sentence 228:
# The association stated that high-quality resources and high-quality productivity are further concentrated in large gold companies.
# -----
#
# Article 215, Sentence 249:
# The fall in gold prices has also prompted an increase in demand from industrial gold companies.
# -----
#
# Article 215, Sentence 266:
# The improvement in the macro economy and the fall in gold prices have caused physical gold investment to continue the high heat in the fourth quarter of last year, with a sharp rise year-on-year.
# -----
#
# Article 215, Sentence 306:
# In the first quarter of 2021, with the turnaround of the global epidemic and the steady progress of vaccination, as well as the continuous strengthening of the U.S. dollar under the large-scale fiscal stimulus of the Biden government of the United States, the price of gold fluctuated and corrected during the period.
#
# -----
#
# Article 216, Sentence 0:
# Gold Scarf Hand Knit https://t.co/PBHEvH1RVj via @EtsySocial #etsymntt #handmade #gold #lacescarf https://t.co/rAfo8YSJXK
#
# -----
#
# Article 221, Sentence 7:
# Gold lagging.
# -----
#
# Article 222, Sentence 0:
# My #RTRNaps are:  She's All In Gold @ 14:20 Asterion Forlonge @ 16:15 Major Valentine @ 16:00  Sponsored by… https://t.co/HsSJLCnASM
#
# -----
#
# Article 223, Sentence 335:
# About Resolution Minerals Ltd: Resolution Minerals Ltd (ASX:RML) is a mining company engaged in the acquisition, exploration and development of precious and battery metals - such as gold, copper, cobalt, and vanadium.
# -----
#
# Article 223, Sentence 442:
# It has since aquired the Snettisham Vanadium Project and more entered into a binding agreement witth Millrock Resources to earn up to 80% of the highly prospective 64North Gold Project.
# -----
#
# Article 224, Sentence 0:
# Two teams I was on with Gold &amp; Silver.
# -----
#
# Article 227, Sentence 26:
# The karate fighters of the Azerbaijan Emergencies Ministry's Sports and Recreation Center enriched the country's medal haul with gold and silver medals.  More than 450 karate fighters from seven countries took part in the international karate tournament.
# -----
#
# Article 227, Sentence 70:
# Nijat Karimli (61 kg) took gold in kumite and silver in the individual championship.
# -----
#
# Article 227, Sentence 87:
# Nihad Karimzade (70 kg) also became a silver medalist.
# -----
#
# Article 227, Sentence 414:
# Rafael Aghayev won a gold medal in karate (kumite) competitions at the 4th Islamic Solidarity Games in Baku.
# -----
#
# Article 227, Sentence 435:
# He secured the gold medal thanks to a victory over Pakistani Ghulam Abbas in the 75kg division final.
# -----
#
# Article 227, Sentence 470:
# She is the owner of the gold medal at the Premier League Karate1 2014 in Almere, bronze at "World Karate Cup 2014", gold at the Premier League Karate1 2015 in Istanbul, silver at the Premier League Karate1 2017, etc.
# -----
#
# Article 227, Sentence 532:
# Rafael Aghayev (60 kg) and Jeyhun Aghasiyev (65 kg) won gold medals among cadets for the first time.
# -----
#
# Article 228, Sentence 53:
# Imbecile Scottie steps on his dick every 5 seconds and basically serves up the company to the shorts on a silver platter.
# -----
#
# Article 231, Sentence 0:
# Vintage Gold Cuff sold for £48 - seller receives £28.67 after fees https://t.co/hbFYTFxM8k
#
# -----
#
# Article 232, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 232, Sentence 4:
# silver 25.90
#
# -----
#
# Article 239, Sentence 0:
# Gold 💫 bagged, learned so much here, and nice people too https://t.co/g9qQ8sbDue
#
# -----
#
# Article 242, Sentence 0:
# Gold Rate Today, 30 April 2021:
# -----
#
# Article 242, Sentence 8:
# Gold, Silver fall, know – what are the 10 grams gold rate today https://t.co/kSVOTVuXw5
#
# -----
#
# Article 243, Sentence 1:
# @PeterSchiff Gold price is suppressed by the government.
# -----
#
# Article 246, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 248, Sentence 14:
# Sterling Silver Bow Brooch #Taxco https://t.co/U4Ehz6ljIJ via @eBa…
#
# -----
#
# Article 249, Sentence 0:
# ✡️🌺💠🌸💖✋💖🌸💠🌺✡️ #Hamsa on Gold #Gifts #plaque #journal #puzzle #dartboard #magnets  https://t.co/zQwvr9rtRc https://t.co/CE9aFn7VlI
#
# -----
#
# Article 250, Sentence 14:
# April 30, 2021 –TheNewswire -Vancouver and Hong Kong- Reyna Silver Corp.
# -----
#
# Article 250, Sentence 113:
# “As we continue to advance our four core properties, Guigui, Batopilas, Medicine Springs and La Reyna, we are pleased to add value to shareholders by selling the Trudeau Gold property, located in one of Canada’s most prolific Gold camps.
# -----
#
# Article 250, Sentence 207:
# We wish Beyond Minerals success with undertaking the exploration of the Trudeau Gold property and look forward to Reyna Silver shareholders benefiting from this asset.”
# -----
#
# Article 250, Sentence 330:
# For Further Information, Please Contact: Reyna Silver Corp.
# -----
#
# Article 250, Sentence 349:
# About Reyna Silver Corp. Reyna Silver Corp. is a silver exploration company with a robust portfolio of Mexican silver assets.
# -----
#
# Article 252, Sentence 0:
# LIVELY RACING BY BOYS.; They Contest for Gold Watches and Medals in the Morning.
# -----
#
# Article 254, Sentence 0:
# #Sale Like and Share if you want this 😃 Tiny Gold Initial Necklace Gold Silver Letter https://t.co/Cxdf2Qgn53 🔥🔥 https://t.co/8YuCfnUI8u
#
# -----
#
# Article 256, Sentence 2083:
# Darüber hinaus meldete das Unternehmen in Verbindung mit der abgeschlossenen Machbarkeitsstudie die erste Reserve von 620.000 Unzen Gold bei Martha Underground ("MUG").
# -----
#
# Article 257, Sentence 4:
# gold loses either way.
# -----
#
# Article 257, Sentence 9:
# if the dollar rises, gold falls.
# -----
#
# Article 257, Sentence 17:
# if the dollar falls, the banks add more shorts so gold doesn't look good
#
# -----
#
# Article 266, Sentence 0:
# BNY Mellon fund laments: ‘We should have bought Bitcoin, not gold' https://t.co/1ku5I9WQH5
#
# -----
#
# Article 268, Sentence 0:
# 2020 Gold Winners of @usaratings by Primos Gin Brand and Craftlink Distillery!
# -----
#
# Article 270, Sentence 0:
# The Edge Singapore | Rotate back to technology stocks, gold,.....
# -----
#
# Article 270, Sentence 13:
# The Edge Singapore | Rotate back to technology stocks, gold, says DBS https://www.theedgesingapore.com/capital/investing-ideas/rotate-back-technology-stocks-gold-says-dbs
#
# -----
#
# Article 271, Sentence 300:
# Vehicle loans and loans against gold jewellery continued to perform well during the month, witnessing accelerated growth, the data showed.
# -----
#
# Article 272, Sentence 0:
# Gold Ranges for GBX - #GC1!
# -----
#
# Article 273, Sentence 22:
# Platinum 1x (100M), Gold 6x (5…
#
# -----
#
# Article 275, Sentence 0:
# Ametrine Earrings 18K Yellow Gold Estate Fine Jewelry Retro Dangle Drop Pear https://t.co/vwQ3y8ZmQ3 eBay https://t.co/zs7GDVHEfC
#
# -----
#
# Article 276, Sentence 0:
# Real Gold 2C Drop Hearts GZP 008 Pendant 2020  ➤ Dhs.  304.
# -----
#
# Article 277, Sentence 20:
# Gold Medal Winter by No… https://t.co/YIOz5It76p
#
# -----
#
# Article 278, Sentence 0:
# END OF Diet ICAN Mock Exams https://t.co/ibU226czJQ   Adekunle Gold |
#
# -----
#
# Article 280, Sentence 0:
# #goldprice  Upward pressure in gold prices, price charts show Gold is trying to break resistance level of past 6 mo… https://t.co/dTklA1O9P1
#
# -----
#
# Article 281, Sentence 0:
# - European Shares Wobble at Month-End - Mixed China data, Commodity FX leads the pack - Gold and silver to consolid… https://t.co/lXaVDEw84x
#
# -----
#
# Article 282, Sentence 0:
# Re: Bitcoin or Gold?.
# -----
#
# Article 285, Sentence 0:
# RT @JJK_Times: 🇯🇵 Jungkook has now two projects officially certified by Recording Industry Association of Japan:  Gold 📀
# -----
#
# Article 286, Sentence 5:
# Gold is one of the most desired and useful metals in the world.
# -----
#
# Article 286, Sentence 40:
# This article could possibly give you more knowledge about the uses of the precious metal gold.
# -----
#
# Article 286, Sentence 80:
# Arguably no other metal has been said to have a record throughout history, with almost every established culture using gold to symbolise power, beauty, purity and accomplishment.
# -----
#
# Article 286, Sentence 112:
# Today, gold still seems to occupy an important place important place in our culture and society people could posibly use it to make our one of the most prized objects: wedding rings, Olympic medals, money, jewellery, Oscars, Grammys, crucifixes, art and many more.
# -----
#
# Article 287, Sentence 452:
# Jeffrey D. Allred, Deseret News Nate Silver, the editor-in-chief of FiveThirtyEight who is a well-known predictor of political elections, last year said “people underrate the chance that Utah could become a swing state in another couple of cycles.”
# -----
#
# Article 287, Sentence 502:
# In 2017, Silver told the Deseret News he’s fascinated by Utah because it looks and breathes like a blue state, even though it’s traditionally red.
# -----
#
# Article 287, Sentence 3345:
# His family businesses are Skyline Sheep Co., as well as Skyline Bit and Spur, a small business that ships horse bridles and silver.
# -----
#
# Article 288, Sentence 0:
# @ACNH_cococross @ACrossing_life Gold nuggets!
# -----
#
# Article 289, Sentence 0:
# Hit Gold and Plat for the first time this season!!
# -----
#
# Article 291, Sentence 0:
# 58mm Large Hoop Earrings, 2.28 Inch Hoop Earrings, Big 14K Gold Filled Women Hoops, Boho Simple 2mm Thick Circle Gy… https://t.co/39RqAILJar
#
# -----
#
# Article 293, Sentence 0:
# The Gold standard 🔥🔥🔥 https://t.co/uhNiNyXbHw
#
# -----
#
# Article 294, Sentence 11:
# Blackheart Gold Pants.
#
# -----
#
# Article 296, Sentence 0:
# GMV Minerals Begins Environmental Studies For Mexican Hat Project   $GMV $GMV.v #gold #goldstocks #juniormining… https://t.co/5yFM5IuZyt
#
# -----
#
# Article 300, Sentence 0:
# Selection Vs Gold Coast
# -----
#
# Article 304, Sentence 0:
# Gold Forecast:
# -----
#
# Article 304, Sentence 8:
# Pay close attention to the rate of change in the yield of bonds, because if it is a slow and gradual rise, then I believe that gold should do fairly well.
# -----
#
# Article 304, Sentence 42:
# Gold markets initially tried to rally during the course of the trading session on Thursday but failed to continue going higher at the 200 day EMA as it continues to be quite resistive.
# -----
#
# Article 304, Sentence 171:
# Furthermore, you have to pay close attention to the US dollar, because the gold market is highly influenced by it.
# -----
#
# Article 304, Sentence 370:
# Until then, I would be hesitant to put a lot of money into the gold market, but it certainly looks as if we are trying to turn things around.
# -----
#
# Article 304, Sentence 441:
# Pay close attention to the rate of change in the yield of bonds, because if it is a slow and gradual rise, then I believe that gold should do fairly well.
#
# -----
#
# Article 305, Sentence 0:
# @MarinaNigrelli Maybe they will Decorate the Dance floor with John Lewis Furniture and Gold Wall Paper!
# -----
#
# Article 306, Sentence 2170:
# &quot;Detective Chinatown 3&quot; won the gold award, &quot;The Great Sister&quot; and &quot;Su Mang&#39;s Covenant&quot; won the silver award, &quot;Assassination of the Novelist&quot; won the bronze award, and &quot;Hello, Li Huanying&quot; won the promotion award.
# -----
#
# Article 307, Sentence 0:
# RT @dazyle_: ⎆ You're gonna love this ⎆  10K White Gold 3 mm Diamond Cut Hoop Earrings 0.6" Diameter  Get your now ➣ https://t.co/MyrpRVXqe…
#
# -----
#
# Article 308, Sentence 0:
# @ZombywoofZ Gold
#
# -----
#
# Article 310, Sentence 0:
# #Jammin' Adekunle Gold ft.
# -----
#
# Article 311, Sentence 190:
# To add more character to her 'fit, she opted for chunky gold accessories which stand out against the color of her dress!
# -----
#
# Article 311, Sentence 453:
# Miss Thailand looks stunning in this glittering gold backless gown that cascades in a tiered ombre tulle skirt.
# -----
#
# Article 312, Sentence 0:
# RT @GreenBull_HC: $DRE $DRE.ax  Drilling completed yesterday at 2, 10km+ Gold corridors:  -19 targets tested  -69 RC holes for 7,082m  -mig…
#
# -----
#
# Article 314, Sentence 2:
# Corsair RM850x 80 Plus V2 Gold Fully Modular PSU $169 Delivered ($0 VIC C&amp;C/ in-Store) @ Centre Com https://t.co/QEtL6cH8X8
#
# -----
#
# Article 315, Sentence 0:
# RT @ColonelKSpeaks: Dashawn Jordan really gonna win the Gold medal at the Olympics riding a Toy Machine board huh. https://t.co/nzX30jGKuB
#
# -----
#
# Article 318, Sentence 0:
# Sandstorm Gold (SAND) Lags Q1 Earnings Estimates.
# -----
#
# Article 318, Sentence 10:
# Posted by: Gold Editor  in XAU/USD Gold US Dollar  16 mins ago  S andstorm Gold (SAND) came out with quarterly earnings of $0.03 per share, missing the Zacks Consensus Estimate of $0.05 per share.
# -----
#
# Article 318, Sentence 83:
# Latest posts by Gold Editor ( see all )
#
# -----
#
# Article 324, Sentence 674:
# Spot gold dropped 0.4% to $1,773.60 an ounce.
# -----
#
# Article 324, Sentence 685:
# U.S. gold futures GCv1 settled down 0.3% at $1,768.3.
#
# -----
#
# Article 328, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Wedding Band Diamonds 0.20ctw 10k Gold Ring Size 7.… https://t.co/4aXtqWNeN6
#
# -----
#
# Article 331, Sentence 0:
# Check #gold on #ebay &gt;&gt; https://t.co/a8cDMHn2q1 || Is Kinross Gold Stock A Good Bet After Dropping 16% In Six Month… https://t.co/T9XipeyJdH
#
# -----
#
# Article 333, Sentence 10:
# The closure of the Ngwarati mine after the death of a worker in a high wall collapse has resulted in a 6% decline in production of platinum, palladium, rhodium, ruthenium, iridium and gold by Zimplats in the March qtr (Q3FY21).
# -----
#
# Article 335, Sentence 0:
# RT @FOREXcom: - European Shares Wobble at Month-End - Mixed China data, Commodity FX leads the pack - Gold and silver to consolidate above…
#
# -----
#
# Article 336, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 337, Sentence 0:
# Gold-standard' swab tests will cost holidaymakers just £45 each.
# -----
#
# Article 337, Sentence 80:
# 'Gold standard' PCR swab tests will continue to be required for all travellers arriving in Britain, despite the Prime Minister previously suggesting that rapid lateral flow tests could be considered for use.
# -----
#
# Article 337, Sentence 230:
# Official packages use gold-standard PCR technology and cost around £200 a head, this is due to fall to £45 by May 17 when some international travel is set to resume.
# -----
#
# Article 338, Sentence 14:
# Posted by: EUR Editor  in EUR  1 min ago  After witnessing good two-way businesses on Thursday, Gold (XAU/USD) is holding on to recent recovery gains amid a broadly subdued US dollar and higher Treasury yields.
# -----
#
# Article 340, Sentence 0:
# @granthpaulsen Mac Jones would look good in the Burgundy and Gold
#
# -----
#
# Article 341, Sentence 331:
# Meanwhile the first fiancée, Carrie Symonds, whose choice of gold wallpaper supposedly sent the prime minister into paroxysms, has been dubbed Carrie Antoinette.
# -----
#
# Article 342, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: BDG 1985 Yellow Gold Drop Armhole Muscle Tank Top.… https://t.co/6Uz6AG9X3j
#
# -----
#
# Article 343, Sentence 0:
# BNY Mellon fund laments it should have bought Bitcoin, not gold - https://t.co/gW8d5SpcC7
#
# -----
#
# Article 344, Sentence 3:
# In the MI Blue &amp; Gold - for 10 seasons in a RO! 💙
# -----
#
# Article 361, Sentence 0:
# All Adekunle Gold fans this is a big banger from the boss, Adekolu gold is a hot 🥵 musician
#
# -----
#
# Article 362, Sentence 0:
# RT @ChironLIOS: Black Gold is what YBN Nahmir wanted to make with Soul Train
#
# -----
#
# Article 363, Sentence 271:
# Since the 18th National Congress of the Communist Party of China, whether it is for domestic investigations and investigations or attending international events, wherever General Secretary Xi Jinping goes, he has talked about the concept that green waters and green mountains are golden mountains and silver mountains.
# -----
#
# Article 365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 367, Sentence 0:
# @caratstalk Gold  SEVENTEEN TOP SOCIAL ARTIST @pledis_17 #세븐틴  #SEVENTEEN_BBMAs
#
# -----
#
# Article 369, Sentence 185:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 373, Sentence 0:
# "He’s predicted pretty much everything to a tee so far.. genuine gold coming from that YouTube.
#
# -----
#
# Article 386, Sentence 0:
# moneycontrol forum messages on Aarti Ind. Aarti getting international recognition for Environment, Sustainability and Governance by way of a gold medal is very creditable.
# -----
#
# Article 387, Sentence 0:
# Or check out all gold watches &gt;&gt;
# -----
#
# Article 387, Sentence 11:
# Rolex Datejust 36 Steel &amp; Gold 16233 Wristwatch - Whi… https://t.co/Zvb6aIbUI2
#
# -----
#
# Article 388, Sentence 75:
# Some gold lock up to be engineered out.
# -----
#
# Article 389, Sentence 79:
# Gold strategic alliance group.
# -----
#
# Article 389, Sentence 86:
# Gold is a strategic marketing alliance of Newfoundland focused precious metals companies collectively committed to bringing awareness to an exciting emerging gold district.
# -----
#
# Article 389, Sentence 117:
# Gold, is focused on creating innovative capital attraction initiatives to promote Newfoundland and the member companies.
# -----
#
# Article 389, Sentence 138:
# Gold will host its launch event, Virtual Investor Days, June 1-3, 2021 online.
# -----
#
# Article 389, Sentence 201:
# Newfoundland is experiencing a modern day gold rush and is a top ranked exploration and mining jurisdiction.
# -----
#
# Article 389, Sentence 277:
# Gold alliance.
# -----
#
# Article 389, Sentence 281:
# With the recent success in gold exploration and discovery Newfoundland there is a hunger for information on exploration programs and everyone’s different strategies,” Michael Collins , President and CEO commented.
# -----
#
# Article 389, Sentence 315:
# “This will be a great forum for investors to get up to date information about  as well as other gold exploration companies in Newfoundland,”   The Founding Member Companies   Newfoundland.
# -----
#
# Article 389, Sentence 351:
# Gold is a strategic marketing alliance established by leaders in Newfoundland and Labrador’s gold exploration and mining sector.
# -----
#
# Article 389, Sentence 478:
# Gold   Newfoundland.
# -----
#
# Article 389, Sentence 482:
# Gold is a strategic marketing alliance comprised of gold exploration and mining companies focused on the advancement of the mineral sector in Canada’s Newfoundland .
# -----
#
# Article 389, Sentence 538:
# Gold is a member of a collective marketing alliance, NLMines.com, focused on bringing awareness to the collective exploration and mining industry in Canada’s Newfoundland & Labrador.
# -----
#
# Article 389, Sentence 570:
# Gold and NLMInes.com are open to all exploration and mining companies which have a primary focus on exploration or mining activities in Newfoundland .
# -----
#
# Article 389, Sentence 703:
# The last 40 years have seen incremental advancements in the understanding of gold mineralization in the camp.
# -----
#
# Article 390, Sentence 0:
# Fool’s Gold TIESTO 24karat Gold Edition with the one and only @tiesto OUT NOW❤️link in bioo ‼️❣️ https://t.co/eq3eGzRV3W
#
# -----
#
# Article 391, Sentence 0:
# RT @SunneeGlobalFC: 2021/04/30 EVM weibo update  Little Silver Bottle 3rd generation upgraded See, touch, feel EVM Little Silver Bottle 3.0…
#
# -----
#
# Article 392, Sentence 7:
# Todays Activities 10:30am Virtual Zumba Gold https://t.co/fsl3VePm6p 2pm Virtual S… https://t.co/PUS2iVWIQK
#
# -----
#
# Article 393, Sentence 65:
# Moreover, she has been staying away from the silver screen in the recent past.
# -----
#
# Article 395, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 402, Sentence 55:
# The aluminium foil tray manufacturer said the new trays, which support a variety of recipes, are produced in a number of colour variations including black, red, gold, green, grey, blue and silver, all of which are fully recyclable.
# -----
#
# Article 403, Sentence 0:
# silver long.
# -----
#
# Article 405, Sentence 0:
# Gold futures ease below Rs 46,900, silver firm: How to trade at current juncture #CommodityNews #Outlook https://t.co/lvSeMxmqki
#
# -----
#
# Article 411, Sentence 285:
# Wang Zheng Kong Weimin Deng Minliang LV Jinqing Liu Yanzi Su Fangjian Du Qian Li Xiao Song Wancheng Zhang Shan Zhang Yan Chen Luchuan Lang Yaojun Hu Yaodong Luan Bo Bo Jinguang Shandong Gold The World of Shandong Gold The Gold Mountain of The World Protect green hills and beautiful scenery Creating benefits for the earth with love Priority to Resources Performance first Innovation oriented About the Report This report properly reflects the fulfillment of social responsibilities by Shandong Gold Mining Co., Ltd. in 2020, and aims to improve communication and strengthen links with stakeholders.
# -----
#
# Article 411, Sentence 435:
# Reporting entity Shandong Gold Mining Co., Ltd. and its affiliates Designation In this report, Shandong Gold Mining Co., Ltd. is referred to as "Shandong Gold", "the company", or "we".
# -----
#
# Article 411, Sentence 802:
# 2020 Corporate Social Responsibility Report Contents 01 About the Report 04 Letter from the Chairman 06 About Shandong Gold 08
# -----
#
# Article 411, Sentence 1692:
# Our gold melting company has been classified as a national green factory, representing the development of Shandong Gold as the first green mining group in the country.
# -----
#
# Article 411, Sentence 1932:
# 2020 Corporate Social Responsibility Report About Shandong Gold Company profile Organizational structure 06 07
# -----
#
# Article 411, Sentence 2060:
# The company is mainly engaged in gold mining.
# -----
#
# Article 411, Sentence 2069:
# We have a complete industrial chain that integrates exploration, mining, ore dressing, melting (refining), and the further processing and sales of gold products.
# -----
#
# Article 411, Sentence 2099:
# We also own the relevant scientific and technological development systems, and is a leader in gold production, resource deposits, economic benefits, scientific and technological levels, and talent reserve in the gold industry in China.
# -----
#
# Article 411, Sentence 2173:
# We are the only enterprise that has three mines with accumulative gold production of over hundred tons in China.
# -----
#
# Article 411, Sentence 2193:
# Among all these mines, Sanshandao Mine, Jiaojia Gold Mine, Xincheng Gold Mine, and Linglong Gold Mine were awarded the title "Top Ten Mines for Gold Production in China" for consecutive years.
# -----
#
# Article 411, Sentence 2231:
# The Veladero mine jointed operated (50%-50% shareholding) with Barrick Gold Corporation is the second largest gold mine in South America.
# -----
#
# Article 411, Sentence 2255:
# Advancedscientific andtechnological Large volumeslevels of gold output Leading position in the gold industry
#
# -----
#
# Article 417, Sentence 9:
# Mahadhir Atan  bad for gold, usualy.
#
# -----
#
# Article 418, Sentence 0:
# Sam Eggington v Carlos Molina for WBC Silver Middle Weight Title   @WBCBoxing How do the rankings work for a Silver… https://t.co/3JjpxZikQF
#
# -----
#
# Article 419, Sentence 0:
# With its LEED Gold certification the 84-metre-high #wooden building @HoHoWien in Vienna is our highlight of the mon… https://t.co/d8DCjNwEk7
#
# -----
#
# Article 421, Sentence 3:
# Gold
#
# -----
#
# Article 422, Sentence 0:
# Pendant Colgante Gold Foil Back Round Brilliant Cut Glass Rhinestone Vintage 1930s Jewelry Vendimia Joyeria April B… https://t.co/5Crrcn1R28
#
# -----
#
# Article 425, Sentence 123:
# Designed by Ludovica and Roberto Palomba and made in Italy, the frame comes in white, gold or graphite.
# -----
#
# Article 426, Sentence 9:
# Stay Gold #Dynamite #BestMusicVideo #iHeartAwards  (@BTS_twt)
#
# -----
#
# Article 429, Sentence 14:
# Silver for PAC direct mail!
# -----
#
# Article 429, Sentence 20:
# Gold for Bilingual Direct Mai… https://t.co/zWMwq4L5lB
#
# -----
#
# Article 430, Sentence 218:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 431, Sentence 0:
# @JagexTyran hello, my account got hit with RWT goldfarming ban while i've never sold or bought any gold.
# -----
#
# Article 435, Sentence 722:
# The agency is "the gold standard of a safety and regulatory organization throughout the world," said Fauci, chief medical adviser to President Biden.
# -----
#
# Article 436, Sentence 0:
# #handmadejewelry 6 Colors Vintage Long Gold Earrings
# -----
#
# Article 437, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 437, Sentence 4:
# At last, rates of silver is live....
#
# -----
#
# Article 438, Sentence 38:
# We’re talking about  Fluffernutter Churros , Pecan Pie Churros , Gold Dusted Churros , and even Sleeping Beauty Churros !
# -----
#
# Article 464, Sentence 0:
# By changing from gold to oil then to fiat, they have an almost unlimited amount of currency backing i.e. they are allowed to print an almost “unlimited” amount of dollars.
# -----
#
# Article 724, Sentence 0:
# He’s been issuing years after years those bad bad useless trust bonds and everyone buys them thinking are solid gold from shitadel!
#
# -----
#
# Article 827, Sentence 0:
# **PART 1: FROM GOLD-BACKED TO USD OIL-TO FIAT BACKED**
#
# -----
#
# Article 829, Sentence 10:
# Most countries use gold.
# -----
#
# Article 829, Sentence 15:
# USD used to be backed in gold.
# -----
#
# Article 852, Sentence 0:
# Liked on YouTube: Gold 3 rewards are broken https://t.co/Et3T2xDkMT
#
# -----
#
# Article 853, Sentence 0:
# I sold the last of mine at 2.1, gold stocks have not been kind to me lately, still hold BRB , NXM and WML but sick of going nowhere while the market rallies..
#
# -----
#
# Article 855, Sentence 2221:
# Since the March 2020 market crunch, the Group has gradually changed its asset allocation to include more exposure to equity and commodities (mostly gold).
# -----
#
# Article 855, Sentence 2249:
# As of 31 st  December 2020 , the bonds exposure, including T-bills, was reduced to 19% of the portfolio (64% as of 31/12/19), whereas the rest of the portfolio of cash, financial assets and financial liabilities ( EUR 104.5 m) included:  a negative net cash position of EUR 9.3 m (-9% of the portfolio) versus a positive net debt position of EUR 27.2 m in 2019 (25% of the portfolio), 19% of gold related exposure (versus 1% as of 31/12/2019), 21% of oil related stocks (none as of 31/12/2019), 4% of silver related stocks (none as of 31/12/2019), 42% of equity (excluding oil) long positions (7% as of 31/12/2019), 4% of equity short positions (2% in 2019), 1% in private equity and credit (3% in 2019).
# -----
#
# Article 855, Sentence 2635:
# It is to be noted that the Gold and Silver positions are priced in USD and as such are included in the former USD exposure.
# -----
#
# Article 856, Sentence 210:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 857, Sentence 11:
# here gold moved from 1765 to 1772 and still in mcx gold is at 46750 strange!
# -----
#
# Article 858, Sentence 0:
# $MINE  today we buy gold plated lambos...
#
# -----
#
# Article 906, Sentence 0:
#     • India's gold demand could falter in June quarter on COVID-19 lockdowns -
#
# -----
#
# Article 908, Sentence 0:
#     India's gold consumption is expected to falter in the June quarter as
#
# -----
#
# Article 959, Sentence 0:
#     • Gold prices edged down as higher U.S. Treasury yields dampened the metal's
#
# -----
#
# Article 988, Sentence 0:
# Silver too if it isn’t tarnished.
# -----
#
# Article 989, Sentence 191:
# The new 11-inch and 12.9-inch iPad Pro will be available in silver and space grey finishes.
# -----
#
# Article 990, Sentence 11:
# People are offloading Gold to move into equity.
# -----
#
# Article 994, Sentence 0:
# NIO long term gold!
#
# -----
#
# Article 997, Sentence 0:
# Ransomware explained: No silver bullet, crooks out of reach.
# -----
#
# Article 997, Sentence 1274:
# “There is no silver bullet, but if we’re going to shift the trajectory of this type of attack the US government has got to get at this with some speed,” said task force co-chair Philip Reiner, CEO of the nonprofit Institute for Security and Technology.
# -----
#
# Article 999, Sentence 0:
# It is more of shortages due to car companies going electric and green deals using up silver.
# -----
#
# Article 1000, Sentence 3:
# This is EXACTLY why BioTox Gold blew up so quickly – Honest Customer Review On BioTox Gold https://t.co/FSytJOak78
#
# -----
#
# Article 1001, Sentence 587:
# NRIs often fail to diversify their investments across asset classes and invest in fixed returns assets like FD’s or physical assets like gold and real estate.
# -----
#
# Article 1003, Sentence 0:
# ...
# #SteelerNation Remember it's Black and Gold not Black and Yellow!
#
# -----
#
# Article 1303, Sentence 50:
# Or do you mean holding btc illegal as they done with gold in 1933?
#
# -----
#
# Article 1304, Sentence 17:
# Gold Mixed Chumps Finals: Cleve… https://t.co/ZILD1p5mEQ
#
# -----
#
# Article 1305, Sentence 0:
# Gold can now be invested in various forms: physical gold, digital gold, gold bonds, gold ETFs and more. . .
# -----
#
# Article 1306, Sentence 0:
# #NP Sean C. Johnson - Silver &amp; Gold (Neo Soul Remix) | https://t.co/IlGD0iUdIC
#
# -----
#
# Article 1307, Sentence 0:
# Re: Bitcoin or Gold?.
# -----
#
# Article 1307, Sentence 7:
# Quote from: BIN-BIN on Today at 07:45:23 AMSince gold is more stable for long-term holding, investors will prefer to go for gold against bitcoin.
# -----
#
# Article 1307, Sentence 38:
# Bitcoin is new, just a decade-old currency, but gold has been around for so many years over 100 years.
# -----
#
# Article 1307, Sentence 177:
# And it is proven that I managed to get a large profit from Bitcoin this year, because the increase in Bitcoin this year is very significant when compared to Gold.
#
# -----
#
# Article 1308, Sentence 191:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 1309, Sentence 0:
# @nielsonTSN1260 @Lieutenant_Eric TSN legal analyst and guy who is the case and solution to over 90% of all silver alerts Eric Macremella.
#
# -----
#
# Article 1310, Sentence 0:
# "TECHNICALS-Spot gold may fall to $1,752 .
# -----
#
# Article 1312, Sentence 9:
# Spot gold <XAU=> may fall to
#
# -----
#
# Article 1345, Sentence 0:
# RT @VincentFaithUK: Excited to share the latest addition to my #etsy shop: 8mm Black Tungsten Ring with Rose Gold Groove - Mens - Womens -…
#
# -----
#
# Article 1347, Sentence 0:
# Gold rush I vote #Louies for #BestFanArmy at the #iHeartAwards https://t.co/XmyXZUgo9T
#
# -----
#
# Article 1350, Sentence 0:
# @caratstalk Gold  SEVENTEEN TOP SOCIAL ARTIST @pledis_17 #세븐틴 #BBMAs #SEVENTEEN_BBMAs
#
# -----
#
# Article 1351, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1352, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1355, Sentence 0:
# @Thomasachocolat Gold morning&lt;3
#
# -----
#
# Article 1360, Sentence 0:
# RT @echisanchan: Team H - Gold Digger #NowPlaying on Kpopway Mixtape, https://t.co/K5D79787Qt
#
# -----
#
# Article 1364, Sentence 8:
# Buy crypto gold AABBG!"
#
# -----
#
# Article 1365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1367, Sentence 0:
# renaming Bella to Comedy Gold bc holy shit
#
# -----
#
# Article 1374, Sentence 36:
# but there's a lot more to learn about gold HERE As a country, Australia was said to be developing in the global mining sector.
# -----
#
# Article 1374, Sentence 96:
# Gold benefits from diverse sources of potential demand, a luxury good and a technology component.
# -----
#
# Article 1375, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1376, Sentence 0:
# ⚠️INSURERS⚠️   Who will take Gold at the #InsAwards21?
# -----
#
# Article 1378, Sentence 3:
# Moonrise over the ocean - My Ghana My Gold Coast.
# -----
#
# Article 1379, Sentence 148:
# On the basis of preserving the original rural appearance, restore the architectural style of Qiongbei residential houses with &quot;swallowtail dragon ridge, golden mountain silver bow, gray wall and blue tile&quot;, and reshape a brand-new modern beautiful home through artistic design.
# -----
#
# Article 1384, Sentence 18:
# Doggy coin has a bigger market cap than gold.
# -----
#
# Article 1386, Sentence 571:
# Travellers will have to purchase and take gold standard PCR tests upon their return to the UK - which come in at around £120 each and could rack up quite an extra cost for families.
# -----
#
# Article 1388, Sentence 2:
# 1908 SO Bigney Edwardian Gold Filled hinged Bangle Bracelet Amethyst Glass https://t.co/Lg8xho32PG via @Etsy
#
# -----
#
# Article 1389, Sentence 0:
# Rose Gold flower petals, Copper rose petals, rose gold table decor, flower girl petals, wedding, baby shower decor… https://t.co/TGOFXw1zvI
#
# -----
#
# Article 1393, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Gold Coach Crossbody Bag.
# -----
#
# Article 1395, Sentence 1796:
# By Recent Size, Share, Business Strategy, Segmentation, Regional Demand, and In-Depth Insight of Sales, Revenue, Demand, and Growth Factors till 2026 Compaction Equipment Market Provides an In-Depth Insight of Sales, Revenue, Analysis of Growth Factors and Upcoming Trends, Opportunities by Types and Application to 2026 Says Industry Research Biz Silver Ink Market 2020 Growing Rapidly with Modern Trends, Development Strategy, Business Prospect, Revenue, Area Marketplace Expanding, Demand and Forecast to 2025, Says Industry Research Biz
#
# -----
#
# Article 1396, Sentence 57:
# Voting results for the election of directors are as follows: Voting results for the appointment of Deloitte LLP as auditors are as follows: Voting … YAMANA GOLD INC. (TSX:YRI; NYSE:AUY; LSE:AUY) (“Yamana” or “the Company”) herein announces the results of the votes held at the annual meeting of shareholders for the election of directors, the appointment of auditors and the advisory resolution on executive compensation.
# -----
#
# Article 1396, Sentence 397:
# Voting results for the advisory resolution on executive compensation as described in the Company’s 2021 Information Circular are as follows:    Outcome of Vote    Votes By Poll    Votes For    Votes Against   Carried  491,492,155  41,393,924  (92.23%)  (7.77%)    About Yamana  Yamana Gold Inc. is a Canadian-based precious metals producer with significant gold and silver production, development stage properties, exploration properties, and land positions throughout the Americas, including Canada, Brazil, Chile and Argentina.
# -----
#
# Article 1396, Sentence 621:
# Berenberg (Joint UK Corporate Broker)  Matthew Armitt / Jennifer Wyllie / Detlir Elezi Telephone: +44 (0) 20 3207 7800  Credit Suisse (Joint UK Corporate Broker)  Ben Lawrence / David Nangle Telephone: +44 (0) 20 7888 8888 News Provided by GlobeNewswire via QuoteMedia   Are You Investing In Gold Yet?
# -----
#
# Article 1396, Sentence 685:
# What Happened To Gold In Q1?
# -----
#
# Article 1396, Sentence 692:
# Which Gold Stocks To Watch In 2021?
# -----
#
# Article 1398, Sentence 0:
# Papal Legacy Commemorative 24K Gold Plated Proof Coin Collection and Display Box  https://t.co/fIJxoUn0yh  Papal Le… https://t.co/YkKHryuQpQ
#
# -----
#
# Article 1399, Sentence 5:
# Gold
#
# -----
#
# Article 1401, Sentence 0:
# Just saw this on Amazon: 2020 Apple iPad (10.2-inch, Wi-Fi, 128GB) - Gold (8th Generation) by Apple for $395.00… https://t.co/wFhTUaPb8G
#
# -----
#
# Article 1403, Sentence 0:
# Originally posted by stezz: ↑ Just digging around the tenements near Empress Springs:https://www.resources.qld.gov.au/__data/assets/pdf_file/0004/1497118/recently-granted-tenures-july-2020.pdfhttps://www.finrank.biz/esmeralda-gold-field-a-new-beginning/
# -----
#
# Article 1404, Sentence 0:
# I am so saving your comment, this is gold!
#
# -----
#
# Article 1405, Sentence 0:
# Same here, 50k long and I’m selling 10 gold bars tomorrow, loading up on any dip.#YOLOLONGMNMD
#
# -----
#
# Article 1408, Sentence 7:
# That album is forever Gold bruh               SEX OVER LOVE
#
# -----
#
# Article 1411, Sentence 24:
# Spot gold falls after strong U.S. economic data on Thursday (Adds comments, details and updates prices)By Sethuraman N R and Peter HobsonApril 30 (Reuters) -
# -----
#
# Article 1411, Sentence 317:
# spot gold XAU= was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 1411, Sentence 333:
# U.S. gold futures GCv1 were steady at $1,769.00.Data showed on Thursday that U.S. economic growth accelerated in the first quarter.
# -----
#
# Article 1412, Sentence 0:
# Here's my rating for today's episode:  The Avengers: Earth's Mightiest Heroes: "Emperor Stark": 2 out of 3 Gold Sta… https://t.co/Qt8alAXb6L
#
# -----
#
# Article 1415, Sentence 45:
# There will never be a single XLM added to circulation-- in that respect, it's as good as gold.
# -----
#
# Article 1415, Sentence 79:
# So it's both a store of wealth as well as a currency (it's digital gold and digital dollar at once!)
# -----
#
# Article 1419, Sentence 0:
# @VMusinachirevo 🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩  Tattoos  Nose ring Belly button ring More than 3 piercings Gold teeth Missing front tee… https://t.co/3iOGvibr2j
#
# -----
#
# Article 1421, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1423, Sentence 3:
# After the correction of gold, it continues to fall, and gold trend analysis and operation suggestions.
# -----
#
# Article 1423, Sentence 39:
# The U.S. Index tends to stabilize the wave and pull up, but the bullish trend of the gold 4-hour cycle does not change, and the short trend fails to form, so it will not directly fall.
# -----
#
# Article 1423, Sentence 430:
# In summary, gold adopts a high-altitude, low-to-multiple layout during the day.
# -----
#
# Article 1425, Sentence 0:
# RT @aguila_gold: Great graphics as always from @VisualCap on the #gold industry.
# -----
#
# Article 1425, Sentence 16:
# Gold price now gradually testing 2 month high  https://t…
#
# -----
#
# Article 1427, Sentence 760:
# The Crypto Daily – Movers and Shakers – April 30th, 2021 Silver Price Daily Forecast – Silver Moves Lower As Treasury Yields Rise Why Shares Of Ford Are Down By 9% Today?
# -----
#
# Article 1427, Sentence 795:
# Crude Oil Price Update – Trading on Strong Side of Short-Term Retracement Zone at $63.47 to $62.29 Comcast Shares Rise After Q1 Earnings Blow Past Estimates; Target Price $65 Gold Price Prediction – Prices Slip on Strong GDP Figures
#
# -----
#
# Article 1429, Sentence 663:
# Godfrey Oluka, an environment specialist at the United Nations Development Programme, said the new funding – in a year, that marks the beginning of the UN’s Decade for Ecosystem Restoration – may just be the silver lining the initiative needed.
# -----
#
# Article 1435, Sentence 0:
# @R3Mitul Gold wala
# -----
#
# Article 1436, Sentence 2:
# successful March quarter exploration expected to underpin Pickle Crow gold resource update in July.
# -----
#
# Article 1436, Sentence 17:
# The current , -metre drill campaign remains on track for completion by mid-year and continues to identify additional high-grade gold mineralisation outside the inferred resource.
# -----
#
# Article 1437, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Michael Kors Patent Leather Slingback Gold 10M.… https://t.co/33pHtREIxE
#
# -----
#
# Article 1438, Sentence 0:
# Large Adjustable Round Pure Polished Brass Gold Ring Blank Base with a 25mm Bezel Tray Lot of 1 by BySupply… https://t.co/BM6w4J51Ho
#
# -----
#
# Article 1440, Sentence 0:
# Shi Jinyuan: Gold and Silver Soaring and Falling Markets and Latest Price Trend Operation Suggestions.
# -----
#
# Article 1440, Sentence 17:
# Market trend analysis: April 30, gold news analysis: Thursday (4.29) gold technical: today&#39;s gold market is after the Asian market rushed higher and the entire European market fell, so the current market day is considered to belong Weak, but from the perspective of the trend, yesterday&#39;s price broke the high point of the rebound before the last decline in 1785, and there are signs of strengthening on the trend.
# -----
#
# Article 1440, Sentence 198:
# The current pressure on the top of gold is 1779-1781-1783, which are 382-0.5-618 after the intraday high of 1798 fell, and the high point of rebound after the first fall below 1780 in the European market is near 1782.
# -----
#
# Article 1440, Sentence 307:
# Gold is currently uncertain whether the market trend is long or short.
# -----
#
# Article 1440, Sentence 452:
# On the whole, today&#39;s gold short-term operation ideas suggest that the callback is mainly long, and the rebound short is supplemented.
# -----
#
# Article 1442, Sentence 250:
# The Orochi V2 features the 2nd -gen Razer Mechanical Mouse Switches, with new gold-plated contact points that the company said are less prone to degrading and have a longer lifespan of up to 60 million clicks.
# -----
#
# Article 1449, Sentence 0:
# Gold is about to break the long time descending channel.
# -----
#
# Article 1449, Sentence 11:
# Gold has been on a decline path within 6 months or so, now by getting support of Ichimuko and gathering strength from the previous bearish leg and also getting provided by enough support from lower boundary of the channel, IS READY to make a move and find its way up.
# -----
#
# Article 1450, Sentence 0:
# Act 1: Plat 1 Act 2: Plat 2 Act 3: Plat 1  EP 2 Act 1: Gold 2 (Hard reset) Act 2: Diamond 3 Act 3: Diamond 3 https://t.co/76g2xFYDk6
#
# -----
#
# Article 1451, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Vintage Music Box Trinket Box Japan Gold / White.… https://t.co/0drkUjNbSr
#
# -----
#
# Article 1452, Sentence 78:
# I had the die cut Viridescent with gold foil paper and thought this was arrangement seems pretty awesome.
# -----
#
# Article 1454, Sentence 0:
# Gold demand rises 37% to 140 tonne in Jan-March 2021 https://t.co/i2YcX8CJFT
#
# -----
#
# Article 1458, Sentence 0:
# Victorian Sterling Silver with 14KT Gold Guilded over 925 24.0 by TamisVintageShop https://t.co/KPBJQ7cphW via @Etsy
#
# -----
#
# Article 1459, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1462, Sentence 0:
# Green is the Gold Standard https://t.co/Y9WQXRWpjN
#
# -----
#
# Article 1465, Sentence 0:
# I've got no Reddit gold, but gold's decadent."
#
# -----
#
# Article 1466, Sentence 0:
# RT @collectGoldRush: PRE-ORDER NOW 👉 2021 Gold Rush Autographed Football Jersey Edition Series 4!
# -----
#
# Article 1470, Sentence 0:
# Quality shirts available for 3500 only  Location: Lagos  Bam Bam Cardi B Adekunle Gold Laycon
# -----
#
# Article 1474, Sentence 0:
# Treasure hunters hope to dig up 48 chests of "Himmler’s gold" buried in Poland.
# -----
#
# Article 1474, Sentence 68:
# There may be up to 10 tons of gold and other riches to be found in 48 chests, worth more than EUR 547 million.
# -----
#
# Article 1475, Sentence 0:
# $HOFV pure gold
#
# -----
#
# Article 1477, Sentence 20:
# Printer wud jam if gold takes off.
#
# -----
#
# Article 1478, Sentence 0:
# @FutPatery Gold or premium gold my friend ?
#
# -----
#
# Article 1479, Sentence 20:
# Gold pulling back to a… https://t.co/Gs4Y2jkdfR
#
# -----
#
# Article 1480, Sentence 0:
# Silver Price Analysis: XAG/USD to resume the core uptrend above $30.72 – Credit Suisse.
# -----
#
# Article 1480, Sentence 45:
# What’s more, silver is expected to outperform gold.
# -----
#
# Article 1480, Sentence 56:
# See – Silver Price Analysis: XAG/USD to nosedive towards $21.50 by year-end – CE  Silver maintains a long-term base  “Silver stays trapped in a turgid range below the 50% retracement of the 2011/2020 bear market at $30.72.
# -----
#
# Article 1480, Sentence 171:
# “Silver is still expected to on balance outperform Gold with the trend for the Gold/Silver ratio still seen lower, despite the recent loss of momentum.”
#
# -----
#
# Article 1482, Sentence 166:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 1484, Sentence 3:
# Analysis of the latest market trend of gold and crude oil and the latest operational recommendations.
# -----
#
# Article 1484, Sentence 20:
# ===Thursday, April 30 (April 29), international gold from a technical point of view, from the daily line analysis, the daily line recorded a long shadow line and a small positive line, the current gold price daily close is still stable at the overall
# -----
#
# Article 1484, Sentence 126:
# The hourly line shows that the short-term bottoming and reversal bring the hourly line technical indicators short-term upward and longer-term technical indicators form, forming a short-term gold cross-to-many guidance pattern.
# -----
#
# Article 1488, Sentence 0:
# Gold Price Analysis: XAU/USD to extend the downside on a close below 21-DMA at $1756 https://t.co/ulcdr5mDJL #Gold #XAUUSD
#
# -----
#
# Article 1491, Sentence 0:
# @logmyg @BTS_twt Gold  I vote 'BTSARMY' ( #BTSArmy )for #BestFanArmy at #iHeartAwards !
# -----
#
# Article 1492, Sentence 6:
# Your gold means nothing to me
#
# -----
#
# Article 1495, Sentence 0:
# [𝗖𝗛𝗢𝗢𝗦𝗘 𝗬𝗢𝗨𝗥 𝗙𝗜𝗚𝗛𝗧𝗘𝗥]  ✨Boy With Luv ⚔ Dynamite?  ✨Stay Gold ⚔ Film Out?   ✨Life Goes On ⚔ ON?
# -----
#
# Article 1497, Sentence 521:
# iHerb Singapore)California Gold Nutrition, Trans-Resveratrol, S$23.24California Gold Nutrition, Trans-Resveratrol.
# -----
#
# Articles found: 562

# %%
# Until this point, we haven't handled false negatives. This happens when spaCy treats a sentence as if it's not finance-related, when in reality it is. In other words, there are several other aliases that can be used to refer to gold or silver. For example, the XAU/USD alias will almost certainly refer to the gold price per troy ounce in US dollars, and it is commonly used when talking about price events. So, let's add four more patterns to handle false negatives.

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create EntityRuler instance
ruler = EntityRuler(nlp)

# Define patterns for the new entities
patterns = [
    {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}, {"LOWER": {"IN": ["price", "market", "commodity"]}}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}, {"LOWER": {"IN": ["price", "market", "commodity"]}}]},
    {"label": "COMMODITY", "pattern": "XAU/USD"}, # Added
    {"label": "COMMODITY", "pattern": "XAUUSD"}, # Added
    {"label": "COMMODITY", "pattern": "XAG/USD"}, # Added
    {"label": "COMMODITY", "pattern": "XAGUSD"}, # Added
]

# Add patterns to the EntityRuler
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Read articles from file
with open("sample.txt", "r", encoding="utf-8") as file:
    articles = file.readlines()

# Initialize counter
article_count = 0

# Iterate through all articles
for i, article in enumerate(articles, start=1):
    doc = nlp(article)
    
    # Iterate through sentences in the article and print those containing "COMMODITY"
    for sent in doc.sents:
        sent_entities = [entity.text for entity in sent.ents if entity.label_ == "COMMODITY"]
        
        if sent_entities:
            article_count += 1
            print(f"Article {i}, Sentence {sent.start}:")
            print(sent.text)
            print("-----\n")

# Print the total number of articles found
print(f"Articles found: {article_count}")
# Out:
# Article 1, Sentence 0:
# @fansoniclove Gold the Tenrec
#
# -----
#
# Article 2, Sentence 43:
# Sampson registered a score of 462 points to claim gold in the three positions event.
# -----
#
# Article 2, Sentence 82:
# The score was also notably higher than what Italy's Niccolo Campriani (458.8) and Poland's Tomasz Bartnik (460.4) produced to win gold at the 2016 Olympics and 2018 world championships respectively.
# -----
#
# Article 3, Sentence 73:
# One of those tenements from my reckoning hosts a copper gold resource another has a copper prospect.
# -----
#
# Article 4, Sentence 6:
# Hey guys what is gold's history in May?
#
# -----
#
# Article 5, Sentence 0:
# Good time to invest in gold?"
#
# -----
#
# Article 6, Sentence 0:
# Gold edges lower as firmer US yields pinch appeal https://t.co/P0HPkmXvBZ
#
# -----
#
# Article 7, Sentence 354:
# In both transactions, there was a critical decision about the heritage of the Ghanaian young person; because this gold resource, which is a Ghanaian resource was being treated in a certain way, was it being treated in the right way to guarantee the future of the young people that today Sam Jonah is concerned about?
# -----
#
# Article 13, Sentence 8:
# Trade range 1.40 -1.80  Gold falls all eyes on FED rate decision https://t.co/BgU5kmqPX2
#
# -----
#
# Article 14, Sentence 4:
# I read somewhere that ounces of gold per person were almost constant in history, but not the money...  all previous reserve currencies failed, probably it is dollar turn with Modern Monetary theory at WH
#
# -----
#
# Article 15, Sentence 0:
# @chidinmaekile Adekunle Gold it will go along way in my studies and that of my siblings🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏… https://t.co/JtY9VgSARn
#
# -----
#
# Article 16, Sentence 0:
# Gold Dust Box, 19th-20th century https://t.co/TWBhpLY77c #africanart #brooklynmuseum https://t.co/tlsFXJZV1Y
#
# -----
#
# Article 17, Sentence 0:
# Gold Price News and Forecast: XAU/USD is trapped in daily support and resistance.
# -----
#
# Article 17, Sentence 43:
# Gold steps back from intraday high while flashing $1,772 as a quote amid Friday’s Asian session.
# -----
#
# Article 19, Sentence 173:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 20, Sentence 0:
# RT @RoKhanna: #Bitcoin uses energy like cars, gold, &amp; finance.
# -----
#
# Article 21, Sentence 0:
# Re: Can Crypto be more valuable than gold?.
# -----
#
# Article 21, Sentence 11:
# BTC is more valuable than Gold right now and many crypto projects will join soon, crypto is a work in progress and we are getting nearer to mass adoption finally, Gold is still a good investment choice but the future is just more into technology this days
#
# -----
#
# Article 22, Sentence 0:
# Study the table to answer question 4 &amp; 5   Sexoverlove   Adekunle Gold SWBtheAlbum https://t.co/cFb6cgX2M3
#
# -----
#
# Article 23, Sentence 0:
# Every post and comment you have ever made was related to persuading people to buy silver.
#
# -----
#
# Article 24, Sentence 0:
# Gold comments on April 30, 2021: #XAUUSD #PREMIUM #comextips2021 #goldtips #comexsignals #signals https://t.co/ebw20MTytG
#
# -----
#
# Article 25, Sentence 13:
# Metal: Gold filled  .
# -----
#
# Article 26, Sentence 42:
# One of my other gold/copper plays has a Nil desperandum target too.
# -----
#
# Article 27, Sentence 0:
# Some very old gold.
# -----
#
# Article 27, Sentence 5:
# POLICIA NACIONAL investigators traced to Calpe a 716 gold coin that was offered for sale online.
# -----
#
# Article 27, Sentence 22:
# Only 24 of the gold dinars that were minted in Cordoba and  amongst the first in circulation following the Moorish conquest of Spain have ever been located.
# -----
#
# Article 30, Sentence 3212:
# In CIS, sales declined, affected by sluggish demand for mining equipment in coal mines and depreciation of the Russian ruble, while demand was steady in gold mines and that for construction equipment was on a recovery track in infrastructure development and energy-related sectors.
# -----
#
# Article 30, Sentence 3886:
# Furthermore, Komatsu projects that demand for mining equipment will remain steady in iron ore, copper, and gold mines, while it will enter a recovery track in coal mines.
# -----
#
# Article 32, Sentence 0:
# $AITX the bears are retards just leave them be Us bulls know that we’re holding gold.
# -----
#
# Article 33, Sentence 8:
# Gold foil, treated paper, sharpie, cardboard https://t.co/qOZlHkuxrT
#
# -----
#
# Article 35, Sentence 0:
# @ApplWatcher Gold standard?
# -----
#
# Article 36, Sentence 0:
# RT @met_greekroman: Gold earring with head of an antelope, 4th–3rd century B.C. https://t.co/hMRLU72HaW #greekromanart #metmuseum https://t…
#
# -----
#
# Article 37, Sentence 472:
# I am clearly not qualified to speak on the issue, of course!LeftYahoo had a good point about the silver lining here, though - we get the full trial results that much earlier, with it having been halted.
# -----
#
# Article 38, Sentence 0:
# Here's a custom 14k yellow gold design for oval fans!
# -----
#
# Article 47, Sentence 9:
# % and ameros fag says yields support gold rise
#
# -----
#
# Article 48, Sentence 0:
# https://t.co/GcrC4xmcJF 18K White Gold Cubic Zirconia Round Necklace &amp; Earrings Wedding Set  £9.99!
# -----
#
# Article 49, Sentence 0:
# Gold price trading in neutral territory following rising inflation, U.S. personal income grows 21.1% in March… https://t.co/bvJEdowf6g
#
# -----
#
# Article 50, Sentence 0:
# Gold Price Today April 30: Gold Rate Continues To Fall, Check City-Wise Price List https://t.co/HGRF8zgSS9
#
# -----
#
# Article 54, Sentence 318:
# Studio Metallurgy       If you’re looking for statement jewellery, then Studio Metallurgy gold-plated pieces are a worthy investment and contribution.
# -----
#
# Article 54, Sentence 560:
# Love Letter      Gold vermeil, sterling silver and recycled plastic – the jewellery at Love Letter is unique in all its form and can serve as a good reminder of happier days ahead.
# -----
#
# Article 55, Sentence 0:
# Three National Honorary Gold Medal Winners Internal / External Relations and Information Division ‌ Deputy Director… https://t.co/aRYNYbRhj0
#
# -----
#
# Article 56, Sentence 339:
# The latest 10-year US bond yield was reported at 1.645%; spot gold was reported at US$1,770.87 per ounce.
# -----
#
# Article 58, Sentence 0:
# Solid U.S. Values, Bond Yields, and GDP Put Pressure on Gold   https://t.co/QkUUeVPsGI
# -----
#
# Article 61, Sentence 58:
# In the Bitcoin White Paper written by Satoshi, there is one piece of the puzzle left out: references to Bit Gold.
#
# -----
#
# Article 70, Sentence 13:
# Ancient wisdom valuable like gifts of Gold I embark on life, my path is a…
#
# -----
#
# Article 74, Sentence 0:
# Gold £10,000 coin weighing 22lb produced at Royal Mint in Llantrisant - https://t.co/2aR6fnn0cM  The 8in-wide (20cm… https://t.co/7skWbHoa6G
#
# -----
#
# Article 83, Sentence 0:
# In search of                       We lost  Gold                                    diamond https://t.co/Nc4lNUUeiW
#
# -----
#
# Article 84, Sentence 0:
# We have a nice selection of Nahaia 24Kt Gold Skincare bundle offers 😍 for you.
# -----
#
# Article 86, Sentence 0:
# "mine for gold: make something and get real reward.
#
# -----
#
# Article 90, Sentence 0:
# "$AMC Remember the Smaug from Lord of the rings and how he hoards Gold?
# -----
#
# Article 94, Sentence 456:
# If a company owns one mining licence and literally strikes gold, its return on capital could be huge.
# -----
#
# Article 95, Sentence 306:
# These are challenging times around the world, however, a silver lining is that it has allowed certain industries to flourish, such as e-commerce.
# -----
#
# Article 96, Sentence 11:
# Jessica Villarubin took a seat on the last Gold Chair.
# -----
#
# Article 97, Sentence 0:
# RT @lambardferagamo: BNY Mellon fund complains it should have bought #Bitcoin, not #gold
#
# -----
#
# Article 100, Sentence 0:
# What's the difference between Bitcoin cash and Bitcoin gold?
# -----
#
# Article 102, Sentence 0:
# $AITX Long term gold mine.
# -----
#
# Article 106, Sentence 0:
# Gold Glitter Monogram Poker Chip Casino Wedding Napkins https://t.co/qZ6gJf7rb4 via @zazzle
#
# -----
#
# Article 108, Sentence 0:
# Gold futures eke out gain on volatile day, silver near Rs 67,550/kg: What analysts say - Domestic gold prices seesa… https://t.co/w6qkrpNcOA
#
# -----
#
# Article 110, Sentence 0:
# Hit🔥🔥 Laycon Adekunle Gold Burna boy @itsLaycon  @adekunleGOLD  @burnaboy  Now let listen to the songs #laycon #SWBAlbum
#
# -----
#
# Article 112, Sentence 0:
# RT @Trans_Ticketing: We're delighted to welcome @Vix_Technology as Gold Sponsor of the Transport Ticketing Digital Summit!
# -----
#
# Article 115, Sentence 0:
# JPOW is lucky he is a silver fox with lots of tools, wish he would return my calls 😕"
#
# -----
#
# Article 116, Sentence 0:
# RT @CoinBoards: BNY Mellon fund laments it should have bought Bitcoin, not gold https://t.co/fEAjqLWmVG
#
# -----
#
# Article 117, Sentence 0:
# Gold Trend Analysis Update.
# -----
#
# Article 117, Sentence 5:
# Gold has a chance to buy when it drops once more by the daily resistance key level and then hits a low in the beginning of next week.
# -----
#
# Article 117, Sentence 51:
# Gold will rise above 1900 in the short term.
#
# -----
#
# Article 125, Sentence 3:
# does he shit literal gold?
#
# -----
#
# Article 127, Sentence 0:
# Gold | $XAUUSD | $XAU $USD
# -----
#
# Article 127, Sentence 10:
# 📝 Gold: the balance of the week is dynamically down.
# -----
#
# Article 131, Sentence 0:
# Gold Trades Marginally Lower, Silver Edges Higher On MCX  https://t.co/4Im5WckTtN...
# -----
#
# Article 132, Sentence 9:
# That is all true except:Humanity has spent centuries trying to prove that alchemy ( turning metal to gold) is not possible.
# -----
#
# Article 133, Sentence 0:
# $PRU $RMS $NIC $WGX $BGL $PNR Gold Digger: Australia’s big gold miners are getting bigger, and investors should rea… https://t.co/FzT8ReHUff
#
# -----
#
# Article 135, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Sterling Silver &amp; 14K Gold Ring Thailand Size 6.…
# -----
#
# Article 136, Sentence 0:
# fxmimior Bohemian Dainty Gold Big Butterfly Earrings Big Dainty Gold Drop Earrings Statement Charm Earring Body Jew… https://t.co/QRWgZGyoX7
#
# -----
#
# Article 137, Sentence 0:
# Playing now: Fool's Gold - Sofia Carson 🎧 Listen live at https://t.co/keYSgwmSlo 🏳️‍🌈 📻
#
# -----
#
# Article 138, Sentence 0:
# $AABB believe in the vision of a company that wants to change the world with gold backing.
# -----
#
# Article 140, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 142, Sentence 449:
# Gold bullion volumes increased more than 100% year over year and were 982.8 thousand ounces (2019 – 483.0 thousand ounces) while silver bullion volumes were 29.5 million ounces (2019 – 22.8 million ounces).
# -----
#
# Article 144, Sentence 10:
# What’s your problem gold?
# -----
#
# Article 146, Sentence 0:
# RT @SaskOrganics: A big thank you to Sunrise Foods International for their Gold Sponsorship of the Organic Grain Markets Webinar on April 3…
#
# -----
#
# Article 147, Sentence 0:
# Notice To Disregard — GSB Gold Standard Banking Corporation AG.
# -----
#
# Article 147, Sentence 11:
# April 30,  2021  Latest Update:  April 30,  2021 1:45 pm   Less than a minute     HAMBURG, Germany, April 30 (Bernama-GLOBE NEWSWIRE) —  We are advised by GSB GOLD STANDARD BANKING CORPORATION AG that journalists and other readers should disregard the news release, “GSB Group doubts in gold reserves of Karatbars and the V999 Coin as well as the existence of the Osint Group” issued April 28, 2021, over GlobeNewswire.
# -----
#
# Article 149, Sentence 1312:
# Two weeks ago, minister Rachel Maclean accused the council of wearing “gold-tinted lenses” and said a “blank cheque” would not be forthcoming.
# -----
#
# Article 162, Sentence 11:
# Gold doesn't rust 🤣 dogecoin is snake oil.
#
# -----
#
# Article 164, Sentence 376:
# “Over the years, we have excellent performances at the JCDC festival, winning many gold medals as well as silver medals in dance, music and speech,” she said.
# -----
#
# Article 165, Sentence 0:
# How to Find Value of your Gold Piece https://t.co/kWgQxeReOQ
#
# -----
#
# Article 166, Sentence 0:
# RT @_mary_stylinson: @dzuliagrape Night changes vs Fools Gold   I vote #Louies for #BestFanArmy at the #iHeartAwards︎
#
# -----
#
# Article 167, Sentence 0:
# Four Gold Coast teens charged after dangerous joyride in stolen 4WD https://t.co/8dZd0ARkAV #GoldCoastNews https://t.co/9qPAyXu2sw
#
# -----
#
# Article 171, Sentence 26:
# Favorable gold, copper prices that drove ear…
#
# -----
#
# Article 175, Sentence 0:
# Hall Of Fame trainer to set-up stables at the Gold Coast 🌊👇 https://t.co/O5Jrboto7B
#
# -----
#
# Article 178, Sentence 12:
# Gold standard of journalism... anyone?
#
# -----
#
# Article 180, Sentence 12:
# https://www.theaustralian.com.au/business/dgo-gold-aiming-to-strike-a-balance-in-gold-exploration/news-story/231d9ce048bfd7d7f87545741008db15DGO Gold aiming to strike a balance in gold explorationDGO Gold is hoping it has created a strategic investment model that will reinvigorate gold exploration in Australia.
# -----
#
# Article 180, Sentence 40:
# Picture: BloombergDAMON KITNEYVICTORIAN BUSINESS EDITOR6:42PM APRIL 25, 2021Melbourne investment banker Bruce Parncutt calls his latest plaything a “gold discovery company”.
# -----
#
# Article 180, Sentence 64:
# Neither an explorer nor a miner, the ASX-listed DGO Gold — of which Mr Parncutt has been an executive director for the past year — is looking to carve out a unique niche in the Australian gold sector.
# -----
#
# Article 180, Sentence 106:
# Its game plan is to make strategic equity investments in West Australian brownfield gold discoveries, bankroll themwith additional capital and combine them with its own pursuit of largely-ignored exploration opportunities.
# -----
#
# Article 180, Sentence 140:
# Mr Parncutt said he hopes DGO has created a model that can reinvigorate gold exploration in Australia.
# -----
#
# Article 180, Sentence 284:
# As Joseph Gutnick’s exploration director in the late 1980s and early 1990s, Mr Eshuys led the teams that discovered the Plutonic, Bronzewing and Jundee gold deposits and the Cawse nickel deposit.
# -----
#
# Article 180, Sentence 340:
# He is now DGO Gold’s executive chairman and is working closely with Mr Parncutt — who has been on the board since 2018 — and DGO’s management team to develop two sizeable WA gold resources and to explore for more.
# -----
#
# Article 180, Sentence 458:
# Gold directors Ed Eshuys and Bruce Parncutt.
# -----
#
# Article 180, Sentence 466:
# DGO Gold initially evaluated 100 gold explorers and their projects.
# -----
#
# Article 180, Sentence 477:
# Ten ASX juniors made the shortlist before DGO narrowed it down to two, taking strategic stakes in booming Pilbara gold explorer De Grey Mining and Leonora
# -----
#
# Article 180, Sentence 504:
# gold explorer NTM Gold.
# -----
#
# Article 180, Sentence 663:
# ”The strategy has seen DGO Gold shares soar from just 17c four years ago, and $1.70 last year when Mr Parncutt became an executive, to close on Friday at $3.63.They soared over $4 in September last year on the back of the coronavirus-fuelled surge in the gold price, which saw it spike to $US2056 per ounce last August.
# -----
#
# Article 180, Sentence 731:
# While gold prices have trended lower since the start of 2021 amid rising US Treasury yields and an increasingly positive outlook for the global economic recovery, the DGO share price has held up.
# -----
#
# Article 180, Sentence 766:
# DGO now owns 16 per cent of De Grey, which is drilling out a significant Pilbara gold discovery.
# -----
#
# Article 180, Sentence 842:
# Following the merger late last year of NTM Gold with Dacian Gold, DGO will now emerge with a 10 per cent stake in Dacian.
# -----
#
# Article 183, Sentence 0:
# Gold edges lower as firmer US yields pinch appeal https://t.co/h6yCfptLqY
#
# -----
#
# Article 184, Sentence 4:
# ani time blast gold
#
# -----
#
# Article 185, Sentence 0:
# Global gold demand, first quarter near low level for the first time in 13 years Investor sales.
# -----
#
# Article 185, Sentence 25:
# --Global gold demand in the first quarter of this year has remained near its lowest level since 2008, according to a quarterly report released by the World Gold Council (WGC), an international gold research institute.
# -----
#
# Article 185, Sentence 85:
# Last year, as the spread of the new coronavirus hit the global economy, investors were increasingly buying gold as a safe haven.
# -----
#
# Article 185, Sentence 110:
# At the same time, lockdowns to curb the spread of infection have slowed sales of gold jewelery, gold nuggets and gold coins in China and India, which are normally the two biggest consumers.
# -----
#
# Article 185, Sentence 170:
# According to the WGC, global gold demand from January to March this year was 815.7 tons, a slight increase from 813.7 tons in the previous quarter.
# -----
#
# Article 185, Sentence 230:
# On the other hand, exchange-traded fund (ETF) gold holdings fell by 177.9 tons, the largest decline since the fourth quarter of 2013.
# -----
#
# Article 185, Sentence 259:
# Due to the sale by ETF, the gold price fell from the record high of 1 ounce = $ 2072.50 in August last year to around $ 1,700 in March.
# -----
#
# Article 185, Sentence 303:
# In April, ETF sales slowed sharply and gold prices picked up towards $ 1800.
# -----
#
# Article 185, Sentence 319:
# WGC analyst Christian Gopaul said consumers and investors&#39; demand for gold this year is likely to remain resilient, albeit below its recent peak.
# -----
#
# Article 185, Sentence 345:
# Gold purchased by the central bank in the first quarter was 95.5 tonnes, the highest level since the second quarter of last year.
# -----
#
# Article 186, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 188, Sentence 0:
# @AskAmex Gold delta sky miles .
# -----
#
# Article 196, Sentence 0:
# @GlobalBTSVoting Stay Gold  BTSARMY FIGHT
# -----
#
# Article 198, Sentence 15:
# Meanwhile, spot gold was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 198, Sentence 300:
# Meanwhile, spot gold was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 198, Sentence 317:
# U.S. gold futures were steady at $1,769.00.
# -----
#
# Article 198, Sentence 360:
# Silver fell 0.5% to $25.96 per ounce, though was poised for an over 6% monthly gain - its biggest since last December.
# -----
#
# Article 199, Sentence 12:
# Testing 200MA Support:  1⃣ Mag Silver, $MAG 2⃣ Alexco Resources, $AXU 3⃣ Southern Silver, $S…
#
# -----
#
# Article 200, Sentence 13:
# Silver Gold or Platinum.
# -----
#
# Article 201, Sentence 244:
# Tranquil Green, Frost Silver, and Deep sea for fantastic guys.
# -----
#
# Article 204, Sentence 0:
# 👉 $209.99 👈 Apple iPad Air 2 16 GB Gold Renewed @iotcybersec24   #Apple #iPad #Air #2 #16 #GB #Gold #Renewed… https://t.co/DiwpGVADcw
#
# -----
#
# Article 205, Sentence 0:
# @musangpandan02 @geenocure @DocumentingBafe @adepianpratama @Bafeio Gold n Diamond Goooooo
#
# -----
#
# Article 206, Sentence 0:
# RT @NationOnlineMw: The Reserve Bank of Malawi (RBM) is set to start buying gold in a move that may transform the country’s mining industry…
#
# -----
#
# Article 209, Sentence 0:
# Gold Price Today: Yellow metal corrects as bond yields rise ahead of Fed meeting https://t.co/zlxjyFjL3g https://t.co/2FDPSqHyTh
#
# -----
#
# Article 213, Sentence 5:
# Gold c: I appreciate you and your will to fight is what keeps me going!
# -----
#
# Article 215, Sentence 0:
# China&#39;s gold production in the first quarter shrinks by 10% and consumption is 94%.
# -----
#
# Article 215, Sentence 17:
# The China Gold Association announced that the domestic raw material gold production in the first quarter of this year was 74.44 tons, a year-on-year decrease of 9.92%.
# -----
#
# Article 215, Sentence 51:
# Among them, China National Gold, Shandong Gold, Zijin Mining, Shandong Zhaojin and other large gold conglomerates produced 30.78 tons of mineral gold, accounting for the proportion of the country.
# -----
#
# Article 215, Sentence 91:
# According to the association, the actual consumption of gold in the country during the period was 288.2 tons, an increase of 93.9% year-on-year.
# -----
#
# Article 215, Sentence 122:
# Among them, gold jewellery was 169.18 tons, an increase of 83.81%.
# -----
#
# Article 215, Sentence 137:
# Based on the low base caused by the outbreak in the same period last year, and the results of China&#39;s overall epidemic prevention and control and economic and social development gradually appearing, the gold consumption in the first quarter has returned to the level of the same period in 2019.
# -----
#
# Article 215, Sentence 190:
# The scale of domestic gold ETFs continued to grow in the first quarter, with a total increase of 11.5 tons.
# -----
#
# Article 215, Sentence 212:
# As of the end of March, domestic gold ETF holdings were about 72.4 tons.
# -----
#
# Article 215, Sentence 228:
# The association stated that high-quality resources and high-quality productivity are further concentrated in large gold companies.
# -----
#
# Article 215, Sentence 249:
# The fall in gold prices has also prompted an increase in demand from industrial gold companies.
# -----
#
# Article 215, Sentence 266:
# The improvement in the macro economy and the fall in gold prices have caused physical gold investment to continue the high heat in the fourth quarter of last year, with a sharp rise year-on-year.
# -----
#
# Article 215, Sentence 306:
# In the first quarter of 2021, with the turnaround of the global epidemic and the steady progress of vaccination, as well as the continuous strengthening of the U.S. dollar under the large-scale fiscal stimulus of the Biden government of the United States, the price of gold fluctuated and corrected during the period.
#
# -----
#
# Article 216, Sentence 0:
# Gold Scarf Hand Knit https://t.co/PBHEvH1RVj via @EtsySocial #etsymntt #handmade #gold #lacescarf https://t.co/rAfo8YSJXK
#
# -----
#
# Article 221, Sentence 7:
# Gold lagging.
# -----
#
# Article 222, Sentence 0:
# My #RTRNaps are:  She's All In Gold @ 14:20 Asterion Forlonge @ 16:15 Major Valentine @ 16:00  Sponsored by… https://t.co/HsSJLCnASM
#
# -----
#
# Article 223, Sentence 335:
# About Resolution Minerals Ltd: Resolution Minerals Ltd (ASX:RML) is a mining company engaged in the acquisition, exploration and development of precious and battery metals - such as gold, copper, cobalt, and vanadium.
# -----
#
# Article 223, Sentence 442:
# It has since aquired the Snettisham Vanadium Project and more entered into a binding agreement witth Millrock Resources to earn up to 80% of the highly prospective 64North Gold Project.
# -----
#
# Article 224, Sentence 0:
# Two teams I was on with Gold &amp; Silver.
# -----
#
# Article 227, Sentence 26:
# The karate fighters of the Azerbaijan Emergencies Ministry's Sports and Recreation Center enriched the country's medal haul with gold and silver medals.  More than 450 karate fighters from seven countries took part in the international karate tournament.
# -----
#
# Article 227, Sentence 70:
# Nijat Karimli (61 kg) took gold in kumite and silver in the individual championship.
# -----
#
# Article 227, Sentence 87:
# Nihad Karimzade (70 kg) also became a silver medalist.
# -----
#
# Article 227, Sentence 414:
# Rafael Aghayev won a gold medal in karate (kumite) competitions at the 4th Islamic Solidarity Games in Baku.
# -----
#
# Article 227, Sentence 435:
# He secured the gold medal thanks to a victory over Pakistani Ghulam Abbas in the 75kg division final.
# -----
#
# Article 227, Sentence 470:
# She is the owner of the gold medal at the Premier League Karate1 2014 in Almere, bronze at "World Karate Cup 2014", gold at the Premier League Karate1 2015 in Istanbul, silver at the Premier League Karate1 2017, etc.
# -----
#
# Article 227, Sentence 532:
# Rafael Aghayev (60 kg) and Jeyhun Aghasiyev (65 kg) won gold medals among cadets for the first time.
# -----
#
# Article 228, Sentence 53:
# Imbecile Scottie steps on his dick every 5 seconds and basically serves up the company to the shorts on a silver platter.
# -----
#
# Article 231, Sentence 0:
# Vintage Gold Cuff sold for £48 - seller receives £28.67 after fees https://t.co/hbFYTFxM8k
#
# -----
#
# Article 232, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 232, Sentence 4:
# silver 25.90
#
# -----
#
# Article 239, Sentence 0:
# Gold 💫 bagged, learned so much here, and nice people too https://t.co/g9qQ8sbDue
#
# -----
#
# Article 242, Sentence 0:
# Gold Rate Today, 30 April 2021:
# -----
#
# Article 242, Sentence 8:
# Gold, Silver fall, know – what are the 10 grams gold rate today https://t.co/kSVOTVuXw5
#
# -----
#
# Article 243, Sentence 1:
# @PeterSchiff Gold price is suppressed by the government.
# -----
#
# Article 246, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 248, Sentence 14:
# Sterling Silver Bow Brooch #Taxco https://t.co/U4Ehz6ljIJ via @eBa…
#
# -----
#
# Article 249, Sentence 0:
# ✡️🌺💠🌸💖✋💖🌸💠🌺✡️ #Hamsa on Gold #Gifts #plaque #journal #puzzle #dartboard #magnets  https://t.co/zQwvr9rtRc https://t.co/CE9aFn7VlI
#
# -----
#
# Article 250, Sentence 14:
# April 30, 2021 –TheNewswire -Vancouver and Hong Kong- Reyna Silver Corp.
# -----
#
# Article 250, Sentence 113:
# “As we continue to advance our four core properties, Guigui, Batopilas, Medicine Springs and La Reyna, we are pleased to add value to shareholders by selling the Trudeau Gold property, located in one of Canada’s most prolific Gold camps.
# -----
#
# Article 250, Sentence 207:
# We wish Beyond Minerals success with undertaking the exploration of the Trudeau Gold property and look forward to Reyna Silver shareholders benefiting from this asset.”
# -----
#
# Article 250, Sentence 330:
# For Further Information, Please Contact: Reyna Silver Corp.
# -----
#
# Article 250, Sentence 349:
# About Reyna Silver Corp. Reyna Silver Corp. is a silver exploration company with a robust portfolio of Mexican silver assets.
# -----
#
# Article 252, Sentence 0:
# LIVELY RACING BY BOYS.; They Contest for Gold Watches and Medals in the Morning.
# -----
#
# Article 254, Sentence 0:
# #Sale Like and Share if you want this 😃 Tiny Gold Initial Necklace Gold Silver Letter https://t.co/Cxdf2Qgn53 🔥🔥 https://t.co/8YuCfnUI8u
#
# -----
#
# Article 256, Sentence 2083:
# Darüber hinaus meldete das Unternehmen in Verbindung mit der abgeschlossenen Machbarkeitsstudie die erste Reserve von 620.000 Unzen Gold bei Martha Underground ("MUG").
# -----
#
# Article 257, Sentence 4:
# gold loses either way.
# -----
#
# Article 257, Sentence 9:
# if the dollar rises, gold falls.
# -----
#
# Article 257, Sentence 17:
# if the dollar falls, the banks add more shorts so gold doesn't look good
#
# -----
#
# Article 266, Sentence 0:
# BNY Mellon fund laments: ‘We should have bought Bitcoin, not gold' https://t.co/1ku5I9WQH5
#
# -----
#
# Article 268, Sentence 0:
# 2020 Gold Winners of @usaratings by Primos Gin Brand and Craftlink Distillery!
# -----
#
# Article 270, Sentence 0:
# The Edge Singapore | Rotate back to technology stocks, gold,.....
# -----
#
# Article 270, Sentence 13:
# The Edge Singapore | Rotate back to technology stocks, gold, says DBS https://www.theedgesingapore.com/capital/investing-ideas/rotate-back-technology-stocks-gold-says-dbs
#
# -----
#
# Article 271, Sentence 300:
# Vehicle loans and loans against gold jewellery continued to perform well during the month, witnessing accelerated growth, the data showed.
# -----
#
# Article 272, Sentence 0:
# Gold Ranges for GBX - #GC1!
# -----
#
# Article 273, Sentence 22:
# Platinum 1x (100M), Gold 6x (5…
#
# -----
#
# Article 275, Sentence 0:
# Ametrine Earrings 18K Yellow Gold Estate Fine Jewelry Retro Dangle Drop Pear https://t.co/vwQ3y8ZmQ3 eBay https://t.co/zs7GDVHEfC
#
# -----
#
# Article 276, Sentence 0:
# Real Gold 2C Drop Hearts GZP 008 Pendant 2020  ➤ Dhs.  304.
# -----
#
# Article 277, Sentence 20:
# Gold Medal Winter by No… https://t.co/YIOz5It76p
#
# -----
#
# Article 278, Sentence 0:
# END OF Diet ICAN Mock Exams https://t.co/ibU226czJQ   Adekunle Gold |
#
# -----
#
# Article 280, Sentence 0:
# #goldprice  Upward pressure in gold prices, price charts show Gold is trying to break resistance level of past 6 mo… https://t.co/dTklA1O9P1
#
# -----
#
# Article 281, Sentence 0:
# - European Shares Wobble at Month-End - Mixed China data, Commodity FX leads the pack - Gold and silver to consolid… https://t.co/lXaVDEw84x
#
# -----
#
# Article 282, Sentence 0:
# Re: Bitcoin or Gold?.
# -----
#
# Article 285, Sentence 0:
# RT @JJK_Times: 🇯🇵 Jungkook has now two projects officially certified by Recording Industry Association of Japan:  Gold 📀
# -----
#
# Article 286, Sentence 5:
# Gold is one of the most desired and useful metals in the world.
# -----
#
# Article 286, Sentence 40:
# This article could possibly give you more knowledge about the uses of the precious metal gold.
# -----
#
# Article 286, Sentence 80:
# Arguably no other metal has been said to have a record throughout history, with almost every established culture using gold to symbolise power, beauty, purity and accomplishment.
# -----
#
# Article 286, Sentence 112:
# Today, gold still seems to occupy an important place important place in our culture and society people could posibly use it to make our one of the most prized objects: wedding rings, Olympic medals, money, jewellery, Oscars, Grammys, crucifixes, art and many more.
# -----
#
# Article 287, Sentence 452:
# Jeffrey D. Allred, Deseret News Nate Silver, the editor-in-chief of FiveThirtyEight who is a well-known predictor of political elections, last year said “people underrate the chance that Utah could become a swing state in another couple of cycles.”
# -----
#
# Article 287, Sentence 502:
# In 2017, Silver told the Deseret News he’s fascinated by Utah because it looks and breathes like a blue state, even though it’s traditionally red.
# -----
#
# Article 287, Sentence 3345:
# His family businesses are Skyline Sheep Co., as well as Skyline Bit and Spur, a small business that ships horse bridles and silver.
# -----
#
# Article 288, Sentence 0:
# @ACNH_cococross @ACrossing_life Gold nuggets!
# -----
#
# Article 289, Sentence 0:
# Hit Gold and Plat for the first time this season!!
# -----
#
# Article 291, Sentence 0:
# 58mm Large Hoop Earrings, 2.28 Inch Hoop Earrings, Big 14K Gold Filled Women Hoops, Boho Simple 2mm Thick Circle Gy… https://t.co/39RqAILJar
#
# -----
#
# Article 293, Sentence 0:
# The Gold standard 🔥🔥🔥 https://t.co/uhNiNyXbHw
#
# -----
#
# Article 294, Sentence 11:
# Blackheart Gold Pants.
#
# -----
#
# Article 296, Sentence 0:
# GMV Minerals Begins Environmental Studies For Mexican Hat Project   $GMV $GMV.v #gold #goldstocks #juniormining… https://t.co/5yFM5IuZyt
#
# -----
#
# Article 300, Sentence 0:
# Selection Vs Gold Coast
# -----
#
# Article 304, Sentence 0:
# Gold Forecast:
# -----
#
# Article 304, Sentence 8:
# Pay close attention to the rate of change in the yield of bonds, because if it is a slow and gradual rise, then I believe that gold should do fairly well.
# -----
#
# Article 304, Sentence 42:
# Gold markets initially tried to rally during the course of the trading session on Thursday but failed to continue going higher at the 200 day EMA as it continues to be quite resistive.
# -----
#
# Article 304, Sentence 171:
# Furthermore, you have to pay close attention to the US dollar, because the gold market is highly influenced by it.
# -----
#
# Article 304, Sentence 370:
# Until then, I would be hesitant to put a lot of money into the gold market, but it certainly looks as if we are trying to turn things around.
# -----
#
# Article 304, Sentence 441:
# Pay close attention to the rate of change in the yield of bonds, because if it is a slow and gradual rise, then I believe that gold should do fairly well.
#
# -----
#
# Article 305, Sentence 0:
# @MarinaNigrelli Maybe they will Decorate the Dance floor with John Lewis Furniture and Gold Wall Paper!
# -----
#
# Article 306, Sentence 2170:
# &quot;Detective Chinatown 3&quot; won the gold award, &quot;The Great Sister&quot; and &quot;Su Mang&#39;s Covenant&quot; won the silver award, &quot;Assassination of the Novelist&quot; won the bronze award, and &quot;Hello, Li Huanying&quot; won the promotion award.
# -----
#
# Article 307, Sentence 0:
# RT @dazyle_: ⎆ You're gonna love this ⎆  10K White Gold 3 mm Diamond Cut Hoop Earrings 0.6" Diameter  Get your now ➣ https://t.co/MyrpRVXqe…
#
# -----
#
# Article 308, Sentence 0:
# @ZombywoofZ Gold
#
# -----
#
# Article 310, Sentence 0:
# #Jammin' Adekunle Gold ft.
# -----
#
# Article 311, Sentence 190:
# To add more character to her 'fit, she opted for chunky gold accessories which stand out against the color of her dress!
# -----
#
# Article 311, Sentence 453:
# Miss Thailand looks stunning in this glittering gold backless gown that cascades in a tiered ombre tulle skirt.
# -----
#
# Article 312, Sentence 0:
# RT @GreenBull_HC: $DRE $DRE.ax  Drilling completed yesterday at 2, 10km+ Gold corridors:  -19 targets tested  -69 RC holes for 7,082m  -mig…
#
# -----
#
# Article 314, Sentence 2:
# Corsair RM850x 80 Plus V2 Gold Fully Modular PSU $169 Delivered ($0 VIC C&amp;C/ in-Store) @ Centre Com https://t.co/QEtL6cH8X8
#
# -----
#
# Article 315, Sentence 0:
# RT @ColonelKSpeaks: Dashawn Jordan really gonna win the Gold medal at the Olympics riding a Toy Machine board huh. https://t.co/nzX30jGKuB
#
# -----
#
# Article 318, Sentence 0:
# Sandstorm Gold (SAND) Lags Q1 Earnings Estimates.
# -----
#
# Article 318, Sentence 10:
# Posted by: Gold Editor  in XAU/USD Gold US Dollar  16 mins ago  S andstorm Gold (SAND) came out with quarterly earnings of $0.03 per share, missing the Zacks Consensus Estimate of $0.05 per share.
# -----
#
# Article 318, Sentence 83:
# Latest posts by Gold Editor ( see all )
#
# -----
#
# Article 324, Sentence 674:
# Spot gold dropped 0.4% to $1,773.60 an ounce.
# -----
#
# Article 324, Sentence 685:
# U.S. gold futures GCv1 settled down 0.3% at $1,768.3.
#
# -----
#
# Article 328, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Wedding Band Diamonds 0.20ctw 10k Gold Ring Size 7.… https://t.co/4aXtqWNeN6
#
# -----
#
# Article 331, Sentence 0:
# Check #gold on #ebay &gt;&gt; https://t.co/a8cDMHn2q1 || Is Kinross Gold Stock A Good Bet After Dropping 16% In Six Month… https://t.co/T9XipeyJdH
#
# -----
#
# Article 333, Sentence 10:
# The closure of the Ngwarati mine after the death of a worker in a high wall collapse has resulted in a 6% decline in production of platinum, palladium, rhodium, ruthenium, iridium and gold by Zimplats in the March qtr (Q3FY21).
# -----
#
# Article 335, Sentence 0:
# RT @FOREXcom: - European Shares Wobble at Month-End - Mixed China data, Commodity FX leads the pack - Gold and silver to consolidate above…
#
# -----
#
# Article 336, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 337, Sentence 0:
# Gold-standard' swab tests will cost holidaymakers just £45 each.
# -----
#
# Article 337, Sentence 80:
# 'Gold standard' PCR swab tests will continue to be required for all travellers arriving in Britain, despite the Prime Minister previously suggesting that rapid lateral flow tests could be considered for use.
# -----
#
# Article 337, Sentence 230:
# Official packages use gold-standard PCR technology and cost around £200 a head, this is due to fall to £45 by May 17 when some international travel is set to resume.
# -----
#
# Article 338, Sentence 0:
# Gold Price News and Forecast: XAU/USD retreats on US data.
# -----
#
# Article 338, Sentence 14:
# Posted by: EUR Editor  in EUR  1 min ago  After witnessing good two-way businesses on Thursday, Gold (XAU/USD) is holding on to recent recovery gains amid a broadly subdued US dollar and higher Treasury yields.
# -----
#
# Article 340, Sentence 0:
# @granthpaulsen Mac Jones would look good in the Burgundy and Gold
#
# -----
#
# Article 341, Sentence 331:
# Meanwhile the first fiancée, Carrie Symonds, whose choice of gold wallpaper supposedly sent the prime minister into paroxysms, has been dubbed Carrie Antoinette.
# -----
#
# Article 342, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: BDG 1985 Yellow Gold Drop Armhole Muscle Tank Top.… https://t.co/6Uz6AG9X3j
#
# -----
#
# Article 343, Sentence 0:
# BNY Mellon fund laments it should have bought Bitcoin, not gold - https://t.co/gW8d5SpcC7
#
# -----
#
# Article 344, Sentence 3:
# In the MI Blue &amp; Gold - for 10 seasons in a RO! 💙
# -----
#
# Article 361, Sentence 0:
# All Adekunle Gold fans this is a big banger from the boss, Adekolu gold is a hot 🥵 musician
#
# -----
#
# Article 362, Sentence 0:
# RT @ChironLIOS: Black Gold is what YBN Nahmir wanted to make with Soul Train
#
# -----
#
# Article 363, Sentence 271:
# Since the 18th National Congress of the Communist Party of China, whether it is for domestic investigations and investigations or attending international events, wherever General Secretary Xi Jinping goes, he has talked about the concept that green waters and green mountains are golden mountains and silver mountains.
# -----
#
# Article 365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 367, Sentence 0:
# @caratstalk Gold  SEVENTEEN TOP SOCIAL ARTIST @pledis_17 #세븐틴  #SEVENTEEN_BBMAs
#
# -----
#
# Article 369, Sentence 185:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 373, Sentence 0:
# "He’s predicted pretty much everything to a tee so far.. genuine gold coming from that YouTube.
#
# -----
#
# Article 386, Sentence 0:
# moneycontrol forum messages on Aarti Ind. Aarti getting international recognition for Environment, Sustainability and Governance by way of a gold medal is very creditable.
# -----
#
# Article 387, Sentence 0:
# Or check out all gold watches &gt;&gt;
# -----
#
# Article 387, Sentence 11:
# Rolex Datejust 36 Steel &amp; Gold 16233 Wristwatch - Whi… https://t.co/Zvb6aIbUI2
#
# -----
#
# Article 388, Sentence 75:
# Some gold lock up to be engineered out.
# -----
#
# Article 389, Sentence 79:
# Gold strategic alliance group.
# -----
#
# Article 389, Sentence 86:
# Gold is a strategic marketing alliance of Newfoundland focused precious metals companies collectively committed to bringing awareness to an exciting emerging gold district.
# -----
#
# Article 389, Sentence 117:
# Gold, is focused on creating innovative capital attraction initiatives to promote Newfoundland and the member companies.
# -----
#
# Article 389, Sentence 138:
# Gold will host its launch event, Virtual Investor Days, June 1-3, 2021 online.
# -----
#
# Article 389, Sentence 201:
# Newfoundland is experiencing a modern day gold rush and is a top ranked exploration and mining jurisdiction.
# -----
#
# Article 389, Sentence 277:
# Gold alliance.
# -----
#
# Article 389, Sentence 281:
# With the recent success in gold exploration and discovery Newfoundland there is a hunger for information on exploration programs and everyone’s different strategies,” Michael Collins , President and CEO commented.
# -----
#
# Article 389, Sentence 315:
# “This will be a great forum for investors to get up to date information about  as well as other gold exploration companies in Newfoundland,”   The Founding Member Companies   Newfoundland.
# -----
#
# Article 389, Sentence 351:
# Gold is a strategic marketing alliance established by leaders in Newfoundland and Labrador’s gold exploration and mining sector.
# -----
#
# Article 389, Sentence 478:
# Gold   Newfoundland.
# -----
#
# Article 389, Sentence 482:
# Gold is a strategic marketing alliance comprised of gold exploration and mining companies focused on the advancement of the mineral sector in Canada’s Newfoundland .
# -----
#
# Article 389, Sentence 538:
# Gold is a member of a collective marketing alliance, NLMines.com, focused on bringing awareness to the collective exploration and mining industry in Canada’s Newfoundland & Labrador.
# -----
#
# Article 389, Sentence 570:
# Gold and NLMInes.com are open to all exploration and mining companies which have a primary focus on exploration or mining activities in Newfoundland .
# -----
#
# Article 389, Sentence 703:
# The last 40 years have seen incremental advancements in the understanding of gold mineralization in the camp.
# -----
#
# Article 390, Sentence 0:
# Fool’s Gold TIESTO 24karat Gold Edition with the one and only @tiesto OUT NOW❤️link in bioo ‼️❣️ https://t.co/eq3eGzRV3W
#
# -----
#
# Article 391, Sentence 0:
# RT @SunneeGlobalFC: 2021/04/30 EVM weibo update  Little Silver Bottle 3rd generation upgraded See, touch, feel EVM Little Silver Bottle 3.0…
#
# -----
#
# Article 392, Sentence 7:
# Todays Activities 10:30am Virtual Zumba Gold https://t.co/fsl3VePm6p 2pm Virtual S… https://t.co/PUS2iVWIQK
#
# -----
#
# Article 393, Sentence 65:
# Moreover, she has been staying away from the silver screen in the recent past.
# -----
#
# Article 395, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 400, Sentence 0:
# BUY SHORT XAUUSD | Siklus Sami Joyo.
# -----
#
# Article 402, Sentence 55:
# The aluminium foil tray manufacturer said the new trays, which support a variety of recipes, are produced in a number of colour variations including black, red, gold, green, grey, blue and silver, all of which are fully recyclable.
# -----
#
# Article 403, Sentence 0:
# silver long.
# -----
#
# Article 405, Sentence 0:
# Gold futures ease below Rs 46,900, silver firm: How to trade at current juncture #CommodityNews #Outlook https://t.co/lvSeMxmqki
#
# -----
#
# Article 411, Sentence 285:
# Wang Zheng Kong Weimin Deng Minliang LV Jinqing Liu Yanzi Su Fangjian Du Qian Li Xiao Song Wancheng Zhang Shan Zhang Yan Chen Luchuan Lang Yaojun Hu Yaodong Luan Bo Bo Jinguang Shandong Gold The World of Shandong Gold The Gold Mountain of The World Protect green hills and beautiful scenery Creating benefits for the earth with love Priority to Resources Performance first Innovation oriented About the Report This report properly reflects the fulfillment of social responsibilities by Shandong Gold Mining Co., Ltd. in 2020, and aims to improve communication and strengthen links with stakeholders.
# -----
#
# Article 411, Sentence 435:
# Reporting entity Shandong Gold Mining Co., Ltd. and its affiliates Designation In this report, Shandong Gold Mining Co., Ltd. is referred to as "Shandong Gold", "the company", or "we".
# -----
#
# Article 411, Sentence 802:
# 2020 Corporate Social Responsibility Report Contents 01 About the Report 04 Letter from the Chairman 06 About Shandong Gold 08
# -----
#
# Article 411, Sentence 1692:
# Our gold melting company has been classified as a national green factory, representing the development of Shandong Gold as the first green mining group in the country.
# -----
#
# Article 411, Sentence 1932:
# 2020 Corporate Social Responsibility Report About Shandong Gold Company profile Organizational structure 06 07
# -----
#
# Article 411, Sentence 2060:
# The company is mainly engaged in gold mining.
# -----
#
# Article 411, Sentence 2069:
# We have a complete industrial chain that integrates exploration, mining, ore dressing, melting (refining), and the further processing and sales of gold products.
# -----
#
# Article 411, Sentence 2099:
# We also own the relevant scientific and technological development systems, and is a leader in gold production, resource deposits, economic benefits, scientific and technological levels, and talent reserve in the gold industry in China.
# -----
#
# Article 411, Sentence 2173:
# We are the only enterprise that has three mines with accumulative gold production of over hundred tons in China.
# -----
#
# Article 411, Sentence 2193:
# Among all these mines, Sanshandao Mine, Jiaojia Gold Mine, Xincheng Gold Mine, and Linglong Gold Mine were awarded the title "Top Ten Mines for Gold Production in China" for consecutive years.
# -----
#
# Article 411, Sentence 2231:
# The Veladero mine jointed operated (50%-50% shareholding) with Barrick Gold Corporation is the second largest gold mine in South America.
# -----
#
# Article 411, Sentence 2255:
# Advancedscientific andtechnological Large volumeslevels of gold output Leading position in the gold industry
#
# -----
#
# Article 417, Sentence 9:
# Mahadhir Atan  bad for gold, usualy.
#
# -----
#
# Article 418, Sentence 0:
# Sam Eggington v Carlos Molina for WBC Silver Middle Weight Title   @WBCBoxing How do the rankings work for a Silver… https://t.co/3JjpxZikQF
#
# -----
#
# Article 419, Sentence 0:
# With its LEED Gold certification the 84-metre-high #wooden building @HoHoWien in Vienna is our highlight of the mon… https://t.co/d8DCjNwEk7
#
# -----
#
# Article 421, Sentence 3:
# Gold
#
# -----
#
# Article 422, Sentence 0:
# Pendant Colgante Gold Foil Back Round Brilliant Cut Glass Rhinestone Vintage 1930s Jewelry Vendimia Joyeria April B… https://t.co/5Crrcn1R28
#
# -----
#
# Article 425, Sentence 123:
# Designed by Ludovica and Roberto Palomba and made in Italy, the frame comes in white, gold or graphite.
# -----
#
# Article 426, Sentence 9:
# Stay Gold #Dynamite #BestMusicVideo #iHeartAwards  (@BTS_twt)
#
# -----
#
# Article 429, Sentence 14:
# Silver for PAC direct mail!
# -----
#
# Article 429, Sentence 20:
# Gold for Bilingual Direct Mai… https://t.co/zWMwq4L5lB
#
# -----
#
# Article 430, Sentence 218:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 431, Sentence 0:
# @JagexTyran hello, my account got hit with RWT goldfarming ban while i've never sold or bought any gold.
# -----
#
# Article 435, Sentence 722:
# The agency is "the gold standard of a safety and regulatory organization throughout the world," said Fauci, chief medical adviser to President Biden.
# -----
#
# Article 436, Sentence 0:
# #handmadejewelry 6 Colors Vintage Long Gold Earrings
# -----
#
# Article 437, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 437, Sentence 4:
# At last, rates of silver is live....
#
# -----
#
# Article 438, Sentence 38:
# We’re talking about  Fluffernutter Churros , Pecan Pie Churros , Gold Dusted Churros , and even Sleeping Beauty Churros !
# -----
#
# Article 464, Sentence 0:
# By changing from gold to oil then to fiat, they have an almost unlimited amount of currency backing i.e. they are allowed to print an almost “unlimited” amount of dollars.
# -----
#
# Article 724, Sentence 0:
# He’s been issuing years after years those bad bad useless trust bonds and everyone buys them thinking are solid gold from shitadel!
#
# -----
#
# Article 827, Sentence 0:
# **PART 1: FROM GOLD-BACKED TO USD OIL-TO FIAT BACKED**
#
# -----
#
# Article 829, Sentence 10:
# Most countries use gold.
# -----
#
# Article 829, Sentence 15:
# USD used to be backed in gold.
# -----
#
# Article 852, Sentence 0:
# Liked on YouTube: Gold 3 rewards are broken https://t.co/Et3T2xDkMT
#
# -----
#
# Article 853, Sentence 0:
# I sold the last of mine at 2.1, gold stocks have not been kind to me lately, still hold BRB , NXM and WML but sick of going nowhere while the market rallies..
#
# -----
#
# Article 855, Sentence 2221:
# Since the March 2020 market crunch, the Group has gradually changed its asset allocation to include more exposure to equity and commodities (mostly gold).
# -----
#
# Article 855, Sentence 2249:
# As of 31 st  December 2020 , the bonds exposure, including T-bills, was reduced to 19% of the portfolio (64% as of 31/12/19), whereas the rest of the portfolio of cash, financial assets and financial liabilities ( EUR 104.5 m) included:  a negative net cash position of EUR 9.3 m (-9% of the portfolio) versus a positive net debt position of EUR 27.2 m in 2019 (25% of the portfolio), 19% of gold related exposure (versus 1% as of 31/12/2019), 21% of oil related stocks (none as of 31/12/2019), 4% of silver related stocks (none as of 31/12/2019), 42% of equity (excluding oil) long positions (7% as of 31/12/2019), 4% of equity short positions (2% in 2019), 1% in private equity and credit (3% in 2019).
# -----
#
# Article 855, Sentence 2635:
# It is to be noted that the Gold and Silver positions are priced in USD and as such are included in the former USD exposure.
# -----
#
# Article 856, Sentence 210:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 857, Sentence 11:
# here gold moved from 1765 to 1772 and still in mcx gold is at 46750 strange!
# -----
#
# Article 858, Sentence 0:
# $MINE  today we buy gold plated lambos...
#
# -----
#
# Article 906, Sentence 0:
#     • India's gold demand could falter in June quarter on COVID-19 lockdowns -
#
# -----
#
# Article 908, Sentence 0:
#     India's gold consumption is expected to falter in the June quarter as
#
# -----
#
# Article 959, Sentence 0:
#     • Gold prices edged down as higher U.S. Treasury yields dampened the metal's
#
# -----
#
# Article 988, Sentence 0:
# Silver too if it isn’t tarnished.
# -----
#
# Article 989, Sentence 191:
# The new 11-inch and 12.9-inch iPad Pro will be available in silver and space grey finishes.
# -----
#
# Article 990, Sentence 11:
# People are offloading Gold to move into equity.
# -----
#
# Article 994, Sentence 0:
# NIO long term gold!
#
# -----
#
# Article 997, Sentence 0:
# Ransomware explained: No silver bullet, crooks out of reach.
# -----
#
# Article 997, Sentence 1274:
# “There is no silver bullet, but if we’re going to shift the trajectory of this type of attack the US government has got to get at this with some speed,” said task force co-chair Philip Reiner, CEO of the nonprofit Institute for Security and Technology.
# -----
#
# Article 999, Sentence 0:
# It is more of shortages due to car companies going electric and green deals using up silver.
# -----
#
# Article 1000, Sentence 3:
# This is EXACTLY why BioTox Gold blew up so quickly – Honest Customer Review On BioTox Gold https://t.co/FSytJOak78
#
# -----
#
# ...
# #SteelerNation Remember it's Black and Gold not Black and Yellow!
#
# -----
#
# Article 1303, Sentence 50:
# Or do you mean holding btc illegal as they done with gold in 1933?
#
# -----
#
# Article 1304, Sentence 17:
# Gold Mixed Chumps Finals: Cleve… https://t.co/ZILD1p5mEQ
#
# -----
#
# Article 1305, Sentence 0:
# Gold can now be invested in various forms: physical gold, digital gold, gold bonds, gold ETFs and more. . .
# -----
#
# Article 1306, Sentence 0:
# #NP Sean C. Johnson - Silver &amp; Gold (Neo Soul Remix) | https://t.co/IlGD0iUdIC
#
# -----
#
# Article 1307, Sentence 0:
# Re: Bitcoin or Gold?.
# -----
#
# Article 1307, Sentence 7:
# Quote from: BIN-BIN on Today at 07:45:23 AMSince gold is more stable for long-term holding, investors will prefer to go for gold against bitcoin.
# -----
#
# Article 1307, Sentence 38:
# Bitcoin is new, just a decade-old currency, but gold has been around for so many years over 100 years.
# -----
#
# Article 1307, Sentence 177:
# And it is proven that I managed to get a large profit from Bitcoin this year, because the increase in Bitcoin this year is very significant when compared to Gold.
#
# -----
#
# Article 1308, Sentence 191:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 1309, Sentence 0:
# @nielsonTSN1260 @Lieutenant_Eric TSN legal analyst and guy who is the case and solution to over 90% of all silver alerts Eric Macremella.
#
# -----
#
# Article 1310, Sentence 0:
# "TECHNICALS-Spot gold may fall to $1,752 .
# -----
#
# Article 1312, Sentence 9:
# Spot gold <XAU=> may fall to
#
# -----
#
# Article 1345, Sentence 0:
# RT @VincentFaithUK: Excited to share the latest addition to my #etsy shop: 8mm Black Tungsten Ring with Rose Gold Groove - Mens - Womens -…
#
# -----
#
# Article 1347, Sentence 0:
# Gold rush I vote #Louies for #BestFanArmy at the #iHeartAwards https://t.co/XmyXZUgo9T
#
# -----
#
# Article 1350, Sentence 0:
# @caratstalk Gold  SEVENTEEN TOP SOCIAL ARTIST @pledis_17 #세븐틴 #BBMAs #SEVENTEEN_BBMAs
#
# -----
#
# Article 1351, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1352, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1355, Sentence 0:
# @Thomasachocolat Gold morning&lt;3
#
# -----
#
# Article 1360, Sentence 0:
# RT @echisanchan: Team H - Gold Digger #NowPlaying on Kpopway Mixtape, https://t.co/K5D79787Qt
#
# -----
#
# Article 1364, Sentence 8:
# Buy crypto gold AABBG!"
#
# -----
#
# Article 1365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1367, Sentence 0:
# renaming Bella to Comedy Gold bc holy shit
#
# -----
#
# Article 1374, Sentence 36:
# but there's a lot more to learn about gold HERE As a country, Australia was said to be developing in the global mining sector.
# -----
#
# Article 1374, Sentence 96:
# Gold benefits from diverse sources of potential demand, a luxury good and a technology component.
# -----
#
# Article 1375, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1376, Sentence 0:
# ⚠️INSURERS⚠️   Who will take Gold at the #InsAwards21?
# -----
#
# Article 1378, Sentence 3:
# Moonrise over the ocean - My Ghana My Gold Coast.
# -----
#
# Article 1379, Sentence 148:
# On the basis of preserving the original rural appearance, restore the architectural style of Qiongbei residential houses with &quot;swallowtail dragon ridge, golden mountain silver bow, gray wall and blue tile&quot;, and reshape a brand-new modern beautiful home through artistic design.
# -----
#
# Article 1384, Sentence 18:
# Doggy coin has a bigger market cap than gold.
# -----
#
# Article 1386, Sentence 571:
# Travellers will have to purchase and take gold standard PCR tests upon their return to the UK - which come in at around £120 each and could rack up quite an extra cost for families.
# -----
#
# Article 1388, Sentence 2:
# 1908 SO Bigney Edwardian Gold Filled hinged Bangle Bracelet Amethyst Glass https://t.co/Lg8xho32PG via @Etsy
#
# -----
#
# Article 1389, Sentence 0:
# Rose Gold flower petals, Copper rose petals, rose gold table decor, flower girl petals, wedding, baby shower decor… https://t.co/TGOFXw1zvI
#
# -----
#
# Article 1393, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Gold Coach Crossbody Bag.
# -----
#
# Article 1395, Sentence 1796:
# By Recent Size, Share, Business Strategy, Segmentation, Regional Demand, and In-Depth Insight of Sales, Revenue, Demand, and Growth Factors till 2026 Compaction Equipment Market Provides an In-Depth Insight of Sales, Revenue, Analysis of Growth Factors and Upcoming Trends, Opportunities by Types and Application to 2026 Says Industry Research Biz Silver Ink Market 2020 Growing Rapidly with Modern Trends, Development Strategy, Business Prospect, Revenue, Area Marketplace Expanding, Demand and Forecast to 2025, Says Industry Research Biz
#
# -----
#
# Article 1396, Sentence 57:
# Voting results for the election of directors are as follows: Voting results for the appointment of Deloitte LLP as auditors are as follows: Voting … YAMANA GOLD INC. (TSX:YRI; NYSE:AUY; LSE:AUY) (“Yamana” or “the Company”) herein announces the results of the votes held at the annual meeting of shareholders for the election of directors, the appointment of auditors and the advisory resolution on executive compensation.
# -----
#
# Article 1396, Sentence 397:
# Voting results for the advisory resolution on executive compensation as described in the Company’s 2021 Information Circular are as follows:    Outcome of Vote    Votes By Poll    Votes For    Votes Against   Carried  491,492,155  41,393,924  (92.23%)  (7.77%)    About Yamana  Yamana Gold Inc. is a Canadian-based precious metals producer with significant gold and silver production, development stage properties, exploration properties, and land positions throughout the Americas, including Canada, Brazil, Chile and Argentina.
# -----
#
# Article 1396, Sentence 621:
# Berenberg (Joint UK Corporate Broker)  Matthew Armitt / Jennifer Wyllie / Detlir Elezi Telephone: +44 (0) 20 3207 7800  Credit Suisse (Joint UK Corporate Broker)  Ben Lawrence / David Nangle Telephone: +44 (0) 20 7888 8888 News Provided by GlobeNewswire via QuoteMedia   Are You Investing In Gold Yet?
# -----
#
# Article 1396, Sentence 685:
# What Happened To Gold In Q1?
# -----
#
# Article 1396, Sentence 692:
# Which Gold Stocks To Watch In 2021?
# -----
#
# Article 1398, Sentence 0:
# Papal Legacy Commemorative 24K Gold Plated Proof Coin Collection and Display Box  https://t.co/fIJxoUn0yh  Papal Le… https://t.co/YkKHryuQpQ
#
# -----
#
# Article 1399, Sentence 5:
# Gold
#
# -----
#
# Article 1401, Sentence 0:
# Just saw this on Amazon: 2020 Apple iPad (10.2-inch, Wi-Fi, 128GB) - Gold (8th Generation) by Apple for $395.00… https://t.co/wFhTUaPb8G
#
# -----
#
# Article 1403, Sentence 0:
# Originally posted by stezz: ↑ Just digging around the tenements near Empress Springs:https://www.resources.qld.gov.au/__data/assets/pdf_file/0004/1497118/recently-granted-tenures-july-2020.pdfhttps://www.finrank.biz/esmeralda-gold-field-a-new-beginning/
# -----
#
# Article 1404, Sentence 0:
# I am so saving your comment, this is gold!
#
# -----
#
# Article 1405, Sentence 0:
# Same here, 50k long and I’m selling 10 gold bars tomorrow, loading up on any dip.#YOLOLONGMNMD
#
# -----
#
# Article 1408, Sentence 7:
# That album is forever Gold bruh               SEX OVER LOVE
#
# -----
#
# Article 1411, Sentence 24:
# Spot gold falls after strong U.S. economic data on Thursday (Adds comments, details and updates prices)By Sethuraman N R and Peter HobsonApril 30 (Reuters) -
# -----
#
# Article 1411, Sentence 317:
# spot gold XAU= was down 0.2% at $1,769 per ounce by 0910 GMT.
# -----
#
# Article 1411, Sentence 333:
# U.S. gold futures GCv1 were steady at $1,769.00.Data showed on Thursday that U.S. economic growth accelerated in the first quarter.
# -----
#
# Article 1412, Sentence 0:
# Here's my rating for today's episode:  The Avengers: Earth's Mightiest Heroes: "Emperor Stark": 2 out of 3 Gold Sta… https://t.co/Qt8alAXb6L
#
# -----
#
# Article 1415, Sentence 45:
# There will never be a single XLM added to circulation-- in that respect, it's as good as gold.
# -----
#
# Article 1415, Sentence 79:
# So it's both a store of wealth as well as a currency (it's digital gold and digital dollar at once!)
# -----
#
# Article 1419, Sentence 0:
# @VMusinachirevo 🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩  Tattoos  Nose ring Belly button ring More than 3 piercings Gold teeth Missing front tee… https://t.co/3iOGvibr2j
#
# -----
#
# Article 1421, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1423, Sentence 3:
# After the correction of gold, it continues to fall, and gold trend analysis and operation suggestions.
# -----
#
# Article 1423, Sentence 39:
# The U.S. Index tends to stabilize the wave and pull up, but the bullish trend of the gold 4-hour cycle does not change, and the short trend fails to form, so it will not directly fall.
# -----
#
# Article 1423, Sentence 430:
# In summary, gold adopts a high-altitude, low-to-multiple layout during the day.
# -----
#
# Article 1425, Sentence 0:
# RT @aguila_gold: Great graphics as always from @VisualCap on the #gold industry.
# -----
#
# Article 1425, Sentence 16:
# Gold price now gradually testing 2 month high  https://t…
#
# -----
#
# Article 1427, Sentence 760:
# The Crypto Daily – Movers and Shakers – April 30th, 2021 Silver Price Daily Forecast – Silver Moves Lower As Treasury Yields Rise Why Shares Of Ford Are Down By 9% Today?
# -----
#
# Article 1427, Sentence 795:
# Crude Oil Price Update – Trading on Strong Side of Short-Term Retracement Zone at $63.47 to $62.29 Comcast Shares Rise After Q1 Earnings Blow Past Estimates; Target Price $65 Gold Price Prediction – Prices Slip on Strong GDP Figures
#
# -----
#
# Article 1429, Sentence 663:
# Godfrey Oluka, an environment specialist at the United Nations Development Programme, said the new funding – in a year, that marks the beginning of the UN’s Decade for Ecosystem Restoration – may just be the silver lining the initiative needed.
# -----
#
# Article 1435, Sentence 0:
# @R3Mitul Gold wala
# -----
#
# Article 1436, Sentence 2:
# successful March quarter exploration expected to underpin Pickle Crow gold resource update in July.
# -----
#
# Article 1436, Sentence 17:
# The current , -metre drill campaign remains on track for completion by mid-year and continues to identify additional high-grade gold mineralisation outside the inferred resource.
# -----
#
# Article 1437, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Michael Kors Patent Leather Slingback Gold 10M.… https://t.co/33pHtREIxE
#
# -----
#
# Article 1438, Sentence 0:
# Large Adjustable Round Pure Polished Brass Gold Ring Blank Base with a 25mm Bezel Tray Lot of 1 by BySupply… https://t.co/BM6w4J51Ho
#
# -----
#
# Article 1440, Sentence 0:
# Shi Jinyuan: Gold and Silver Soaring and Falling Markets and Latest Price Trend Operation Suggestions.
# -----
#
# Article 1440, Sentence 17:
# Market trend analysis: April 30, gold news analysis: Thursday (4.29) gold technical: today&#39;s gold market is after the Asian market rushed higher and the entire European market fell, so the current market day is considered to belong Weak, but from the perspective of the trend, yesterday&#39;s price broke the high point of the rebound before the last decline in 1785, and there are signs of strengthening on the trend.
# -----
#
# Article 1440, Sentence 198:
# The current pressure on the top of gold is 1779-1781-1783, which are 382-0.5-618 after the intraday high of 1798 fell, and the high point of rebound after the first fall below 1780 in the European market is near 1782.
# -----
#
# Article 1440, Sentence 307:
# Gold is currently uncertain whether the market trend is long or short.
# -----
#
# Article 1440, Sentence 452:
# On the whole, today&#39;s gold short-term operation ideas suggest that the callback is mainly long, and the rebound short is supplemented.
# -----
#
# Article 1442, Sentence 250:
# The Orochi V2 features the 2nd -gen Razer Mechanical Mouse Switches, with new gold-plated contact points that the company said are less prone to degrading and have a longer lifespan of up to 60 million clicks.
# -----
#
# Article 1449, Sentence 0:
# Gold is about to break the long time descending channel.
# -----
#
# Article 1449, Sentence 11:
# Gold has been on a decline path within 6 months or so, now by getting support of Ichimuko and gathering strength from the previous bearish leg and also getting provided by enough support from lower boundary of the channel, IS READY to make a move and find its way up.
# -----
#
# Article 1450, Sentence 0:
# Act 1: Plat 1 Act 2: Plat 2 Act 3: Plat 1  EP 2 Act 1: Gold 2 (Hard reset) Act 2: Diamond 3 Act 3: Diamond 3 https://t.co/76g2xFYDk6
#
# -----
#
# Article 1451, Sentence 0:
# Check out this listing I just added to my #Poshmark closet: Vintage Music Box Trinket Box Japan Gold / White.… https://t.co/0drkUjNbSr
#
# -----
#
# Article 1452, Sentence 78:
# I had the die cut Viridescent with gold foil paper and thought this was arrangement seems pretty awesome.
# -----
#
# Article 1454, Sentence 0:
# Gold demand rises 37% to 140 tonne in Jan-March 2021 https://t.co/i2YcX8CJFT
#
# -----
#
# Article 1458, Sentence 0:
# Victorian Sterling Silver with 14KT Gold Guilded over 925 24.0 by TamisVintageShop https://t.co/KPBJQ7cphW via @Etsy
#
# -----
#
# Article 1459, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1462, Sentence 0:
# Green is the Gold Standard https://t.co/Y9WQXRWpjN
#
# -----
#
# Article 1465, Sentence 0:
# I've got no Reddit gold, but gold's decadent."
#
# -----
#
# Article 1466, Sentence 0:
# RT @collectGoldRush: PRE-ORDER NOW 👉 2021 Gold Rush Autographed Football Jersey Edition Series 4!
# -----
#
# Article 1470, Sentence 0:
# Quality shirts available for 3500 only  Location: Lagos  Bam Bam Cardi B Adekunle Gold Laycon
# -----
#
# Article 1474, Sentence 0:
# Treasure hunters hope to dig up 48 chests of "Himmler’s gold" buried in Poland.
# -----
#
# Article 1474, Sentence 68:
# There may be up to 10 tons of gold and other riches to be found in 48 chests, worth more than EUR 547 million.
# -----
#
# Article 1475, Sentence 0:
# $HOFV pure gold
#
# -----
#
# Article 1477, Sentence 20:
# Printer wud jam if gold takes off.
#
# -----
#
# Article 1478, Sentence 0:
# @FutPatery Gold or premium gold my friend ?
#
# -----
#
# Article 1479, Sentence 20:
# Gold pulling back to a… https://t.co/Gs4Y2jkdfR
#
# -----
#
# Article 1480, Sentence 0:
# Silver Price Analysis: XAG/USD to resume the core uptrend above $30.72 – Credit Suisse.
# -----
#
# Article 1480, Sentence 45:
# What’s more, silver is expected to outperform gold.
# -----
#
# Article 1480, Sentence 56:
# See – Silver Price Analysis: XAG/USD to nosedive towards $21.50 by year-end – CE  Silver maintains a long-term base  “Silver stays trapped in a turgid range below the 50% retracement of the 2011/2020 bear market at $30.72.
# -----
#
# Article 1480, Sentence 171:
# “Silver is still expected to on balance outperform Gold with the trend for the Gold/Silver ratio still seen lower, despite the recent loss of momentum.”
#
# -----
#
# Article 1482, Sentence 166:
# Foreign exchange and gold quotes are provided by Reuters.
# -----
#
# Article 1484, Sentence 3:
# Analysis of the latest market trend of gold and crude oil and the latest operational recommendations.
# -----
#
# Article 1484, Sentence 20:
# ===Thursday, April 30 (April 29), international gold from a technical point of view, from the daily line analysis, the daily line recorded a long shadow line and a small positive line, the current gold price daily close is still stable at the overall
# -----
#
# Article 1484, Sentence 126:
# The hourly line shows that the short-term bottoming and reversal bring the hourly line technical indicators short-term upward and longer-term technical indicators form, forming a short-term gold cross-to-many guidance pattern.
# -----
#
# Article 1488, Sentence 0:
# Gold Price Analysis: XAU/USD to extend the downside on a close below 21-DMA at $1756 https://t.co/ulcdr5mDJL #Gold #XAUUSD
#
# -----
#
# Article 1491, Sentence 0:
# @logmyg @BTS_twt Gold  I vote 'BTSARMY' ( #BTSArmy )for #BestFanArmy at #iHeartAwards !
# -----
#
# Article 1492, Sentence 6:
# Your gold means nothing to me
#
# -----
#
# Article 1495, Sentence 0:
# [𝗖𝗛𝗢𝗢𝗦𝗘 𝗬𝗢𝗨𝗥 𝗙𝗜𝗚𝗛𝗧𝗘𝗥]  ✨Boy With Luv ⚔ Dynamite?  ✨Stay Gold ⚔ Film Out?   ✨Life Goes On ⚔ ON?
# -----
#
# Article 1497, Sentence 521:
# iHerb Singapore)California Gold Nutrition, Trans-Resveratrol, S$23.24California Gold Nutrition, Trans-Resveratrol.
# -----
#
# Articles found: 565

# %%
# Looks like there were three false negatives that we didn't handle before (before: 562 articles found, now: 565 articles found). There were 3 articles mentioning "XAUUSD"/"XAU/USD" or "XAGUSD"/"XAG/USD", but not "gold" or "silver". They were left out before, but now spaCy has added them because we defined these patterns under the "COMMODITY" label.

# %%
# But still, looking at the sentences printed above, we still see many false positives. For example, "Sampson registered a score of 462 points to claim gold in the three positions event." is printed as if gold is mentioned in a finance-related context. It's not. Let's try to remove the first two patterns because these two seem to catch a lot of false positives. If spaCy simply looks for the entities "gold" and "silver", these two are used in a lot of contexts, not just in a financial context.

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create EntityRuler instance
ruler = EntityRuler(nlp)

# Define patterns for the new entities
patterns = [
    # {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}]}, # Removed
    # {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}]}, #Removed
    {"label": "COMMODITY", "pattern": [{"LOWER": "gold"}, {"LOWER": {"IN": ["price", "market", "commodity", "trading", "investment", "bullion", "precious metal"]}}]},
    {"label": "COMMODITY", "pattern": [{"LOWER": "silver"}, {"LOWER": {"IN": ["price", "market", "commodity", "trading", "investment", "bullion", "precious metal"]}}]},
    {"label": "COMMODITY", "pattern": "XAU/USD"},
    {"label": "COMMODITY", "pattern": "XAUUSD"},
    {"label": "COMMODITY", "pattern": "XAG/USD"},
    {"label": "COMMODITY", "pattern": "XAGUSD"},
]

# Add patterns to the EntityRuler
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Read articles from file
with open("sample.txt", "r", encoding="utf-8") as file:
    articles = file.readlines()

# Initialize counter
article_count = 0

# Iterate through all articles
for i, article in enumerate(articles, start=1):
    doc = nlp(article)
    
    # Iterate through sentences in the article and print those containing "COMMODITY"
    for sent in doc.sents:
        sent_entities = [entity.text for entity in sent.ents if entity.label_ == "COMMODITY"]
        
        if sent_entities:
            article_count += 1
            print(f"Article {i}, Sentence {sent.start}:")
            print(sent.text)
            print("-----\n")

# Print the total number of articles found
print(f"Articles found: {article_count}")
# Out:
# Article 17, Sentence 0:
# Gold Price News and Forecast: XAU/USD is trapped in daily support and resistance.
# -----
#
# Article 49, Sentence 0:
# Gold price trading in neutral territory following rising inflation, U.S. personal income grows 21.1% in March… https://t.co/bvJEdowf6g
#
# -----
#
# Article 50, Sentence 0:
# Gold Price Today April 30: Gold Rate Continues To Fall, Check City-Wise Price List https://t.co/HGRF8zgSS9
#
# -----
#
# Article 127, Sentence 0:
# Gold | $XAUUSD | $XAU $USD
# -----
#
# Article 142, Sentence 449:
# Gold bullion volumes increased more than 100% year over year and were 982.8 thousand ounces (2019 – 483.0 thousand ounces) while silver bullion volumes were 29.5 million ounces (2019 – 22.8 million ounces).
# -----
#
# Article 180, Sentence 663:
# ”The strategy has seen DGO Gold shares soar from just 17c four years ago, and $1.70 last year when Mr Parncutt became an executive, to close on Friday at $3.63.They soared over $4 in September last year on the back of the coronavirus-fuelled surge in the gold price, which saw it spike to $US2056 per ounce last August.
# -----
#
# Article 185, Sentence 259:
# Due to the sale by ETF, the gold price fell from the record high of 1 ounce = $ 2072.50 in August last year to around $ 1,700 in March.
# -----
#
# Article 209, Sentence 0:
# Gold Price Today: Yellow metal corrects as bond yields rise ahead of Fed meeting https://t.co/zlxjyFjL3g https://t.co/2FDPSqHyTh
#
# -----
#
# Article 215, Sentence 266:
# The improvement in the macro economy and the fall in gold prices have caused physical gold investment to continue the high heat in the fourth quarter of last year, with a sharp rise year-on-year.
# -----
#
# Article 243, Sentence 1:
# @PeterSchiff Gold price is suppressed by the government.
# -----
#
# Article 304, Sentence 171:
# Furthermore, you have to pay close attention to the US dollar, because the gold market is highly influenced by it.
# -----
#
# Article 304, Sentence 370:
# Until then, I would be hesitant to put a lot of money into the gold market, but it certainly looks as if we are trying to turn things around.
# -----
#
# Article 338, Sentence 0:
# Gold Price News and Forecast: XAU/USD retreats on US data.
# -----
#
# Article 338, Sentence 14:
# Posted by: EUR Editor  in EUR  1 min ago  After witnessing good two-way businesses on Thursday, Gold (XAU/USD) is holding on to recent recovery gains amid a broadly subdued US dollar and higher Treasury yields.
# -----
#
# Article 400, Sentence 0:
# BUY SHORT XAUUSD | Siklus Sami Joyo.
# -----
#
# Article 1216, Sentence 0:
# Gold Price Today: Yellow metal trades higher post Fed meet; Silver May futures rally over 1% https://t.co/7e8mVN64Of
#
# -----
#
# Article 1226, Sentence 0:
# Gold price at $2,300 if not for bitcoin - Bloomberg Intelligence.
# -----
#
# Article 1425, Sentence 16:
# Gold price now gradually testing 2 month high  https://t…
#
# -----
#
# Article 1427, Sentence 795:
# Crude Oil Price Update – Trading on Strong Side of Short-Term Retracement Zone at $63.47 to $62.29 Comcast Shares Rise After Q1 Earnings Blow Past Estimates; Target Price $65 Gold Price Prediction – Prices Slip on Strong GDP Figures
#
# -----
#
# Article 1440, Sentence 17:
# Market trend analysis: April 30, gold news analysis: Thursday (4.29) gold technical: today&#39;s gold market is after the Asian market rushed higher and the entire European market fell, so the current market day is considered to belong Weak, but from the perspective of the trend, yesterday&#39;s price broke the high point of the rebound before the last decline in 1785, and there are signs of strengthening on the trend.
# -----
#
# Article 1480, Sentence 0:
# Silver Price Analysis: XAG/USD to resume the core uptrend above $30.72 – Credit Suisse.
# -----
#
# Article 1484, Sentence 20:
# ===Thursday, April 30 (April 29), international gold from a technical point of view, from the daily line analysis, the daily line recorded a long shadow line and a small positive line, the current gold price daily close is still stable at the overall
# -----
#
# Article 1488, Sentence 0:
# Gold Price Analysis: XAU/USD to extend the downside on a close below 21-DMA at $1756 https://t.co/ulcdr5mDJL #Gold #XAUUSD
#
# -----
#
# Articles found: 23

# %%
# It looks like a lot of false positives have been eliminated now. But looking at sample.txt we can see that now we have a LOT of false negatives. There are more than 23 articles in sample.txt talking about "gold" or "silver" in a financial context, but spaCy only found 23! So let's try to add more finance-related words to the patterns. The goal is for false positives not to occur but to lower false negatives.

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Create EntityRuler instance
ruler = EntityRuler(nlp)

# Define patterns for the new entities
patterns = [
    {"label": "COMMODITY", "pattern": [{"LOWER": {"IN": ["gold"]}}, {"LOWER": {"IN": ["price", "market", "commodity", "trading", "investment", "bullion", "precious metal", "futures", "yield", "contract", "reserve currencies", "modern monetary theory"]}}]}, # Add more finance-related words to the patterns
    {"label": "COMMODITY", "pattern": [{"LOWER": {"IN": ["silver"]}}, {"LOWER": {"IN": ["price", "market", "commodity", "trading", "investment", "bullion", "precious metal", "futures", "yield", "contract", "reserve currencies", "modern monetary theory"]}}]}, # Add more finance-related words to the patterns
    {"label": "COMMODITY", "pattern": "XAU/USD"},
    {"label": "COMMODITY", "pattern": "XAUUSD"},
    {"label": "COMMODITY", "pattern": "XAG/USD"},
    {"label": "COMMODITY", "pattern": "XAGUSD"},
]

# Add patterns to the EntityRuler
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Read articles from file
with open("sample.txt", "r", encoding="utf-8") as file:
    articles = file.readlines()

# Initialize counter
article_count = 0

# Iterate through all articles
for i, article in enumerate(articles, start=1):
    doc = nlp(article)
    
    # Iterate through sentences in the article and print those containing "COMMODITY"
    for sent in doc.sents:
        sent_entities = [entity.text for entity in sent.ents if entity.label_ == "COMMODITY"]
        
        if sent_entities:
            article_count += 1
            print(f"Article {i}, Sentence {sent.start}:")
            print(sent.text)
            print("-----\n")

# Print the total number of articles found
print(f"Articles found: {article_count}")
# Out:
# Article 17, Sentence 0:
# Gold Price News and Forecast: XAU/USD is trapped in daily support and resistance.
# -----
#
# Article 49, Sentence 0:
# Gold price trading in neutral territory following rising inflation, U.S. personal income grows 21.1% in March… https://t.co/bvJEdowf6g
#
# -----
#
# Article 50, Sentence 0:
# Gold Price Today April 30: Gold Rate Continues To Fall, Check City-Wise Price List https://t.co/HGRF8zgSS9
#
# -----
#
# Article 108, Sentence 0:
# Gold futures eke out gain on volatile day, silver near Rs 67,550/kg: What analysts say - Domestic gold prices seesa… https://t.co/w6qkrpNcOA
#
# -----
#
# Article 127, Sentence 0:
# Gold | $XAUUSD | $XAU $USD
# -----
#
# Article 140, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 142, Sentence 449:
# Gold bullion volumes increased more than 100% year over year and were 982.8 thousand ounces (2019 – 483.0 thousand ounces) while silver bullion volumes were 29.5 million ounces (2019 – 22.8 million ounces).
# -----
#
# Article 180, Sentence 663:
# ”The strategy has seen DGO Gold shares soar from just 17c four years ago, and $1.70 last year when Mr Parncutt became an executive, to close on Friday at $3.63.They soared over $4 in September last year on the back of the coronavirus-fuelled surge in the gold price, which saw it spike to $US2056 per ounce last August.
# -----
#
# Article 185, Sentence 259:
# Due to the sale by ETF, the gold price fell from the record high of 1 ounce = $ 2072.50 in August last year to around $ 1,700 in March.
# -----
#
# Article 186, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 198, Sentence 317:
# U.S. gold futures were steady at $1,769.00.
# -----
#
# Article 209, Sentence 0:
# Gold Price Today: Yellow metal corrects as bond yields rise ahead of Fed meeting https://t.co/zlxjyFjL3g https://t.co/2FDPSqHyTh
#
# -----
#
# Article 215, Sentence 266:
# The improvement in the macro economy and the fall in gold prices have caused physical gold investment to continue the high heat in the fourth quarter of last year, with a sharp rise year-on-year.
# -----
#
# Article 232, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 243, Sentence 1:
# @PeterSchiff Gold price is suppressed by the government.
# -----
#
# Article 246, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 304, Sentence 171:
# Furthermore, you have to pay close attention to the US dollar, because the gold market is highly influenced by it.
# -----
#
# Article 304, Sentence 370:
# Until then, I would be hesitant to put a lot of money into the gold market, but it certainly looks as if we are trying to turn things around.
# -----
#
# Article 324, Sentence 685:
# U.S. gold futures GCv1 settled down 0.3% at $1,768.3.
#
# -----
#
# Article 336, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 338, Sentence 0:
# Gold Price News and Forecast: XAU/USD retreats on US data.
# -----
#
# Article 338, Sentence 14:
# Posted by: EUR Editor  in EUR  1 min ago  After witnessing good two-way businesses on Thursday, Gold (XAU/USD) is holding on to recent recovery gains amid a broadly subdued US dollar and higher Treasury yields.
# -----
#
# Article 365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 395, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 400, Sentence 0:
# BUY SHORT XAUUSD | Siklus Sami Joyo.
# -----
#
# Article 405, Sentence 0:
# Gold futures ease below Rs 46,900, silver firm: How to trade at current juncture #CommodityNews #Outlook https://t.co/lvSeMxmqki
#
# -----
#
# Article 437, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1044, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1200, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1214, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1216, Sentence 0:
# Gold Price Today: Yellow metal trades higher post Fed meet; Silver May futures rally over 1% https://t.co/7e8mVN64Of
#
# -----
#
# Article 1226, Sentence 0:
# Gold price at $2,300 if not for bitcoin - Bloomberg Intelligence.
# -----
#
# Article 1242, Sentence 630:
# Meanwhile, after falling $5.60 to $1,768.30 an ounce in the previous session, gold futures are inching up $1.60 to $1,769.90 an ounce.
# -----
#
# Article 1245, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1267, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1272, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1351, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1352, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1365, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1375, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1411, Sentence 333:
# U.S. gold futures GCv1 were steady at $1,769.00.Data showed on Thursday that U.S. economic growth accelerated in the first quarter.
# -----
#
# Article 1421, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1425, Sentence 16:
# Gold price now gradually testing 2 month high  https://t…
#
# -----
#
# Article 1427, Sentence 795:
# Crude Oil Price Update – Trading on Strong Side of Short-Term Retracement Zone at $63.47 to $62.29 Comcast Shares Rise After Q1 Earnings Blow Past Estimates; Target Price $65 Gold Price Prediction – Prices Slip on Strong GDP Figures
#
# -----
#
# Article 1440, Sentence 17:
# Market trend analysis: April 30, gold news analysis: Thursday (4.29) gold technical: today&#39;s gold market is after the Asian market rushed higher and the entire European market fell, so the current market day is considered to belong Weak, but from the perspective of the trend, yesterday&#39;s price broke the high point of the rebound before the last decline in 1785, and there are signs of strengthening on the trend.
# -----
#
# Article 1459, Sentence 0:
# Silver Futures Discussions.
# -----
#
# Article 1480, Sentence 0:
# Silver Price Analysis: XAG/USD to resume the core uptrend above $30.72 – Credit Suisse.
# -----
#
# Article 1484, Sentence 20:
# ===Thursday, April 30 (April 29), international gold from a technical point of view, from the daily line analysis, the daily line recorded a long shadow line and a small positive line, the current gold price daily close is still stable at the overall
# -----
#
# Article 1488, Sentence 0:
# Gold Price Analysis: XAU/USD to extend the downside on a close below 21-DMA at $1756 https://t.co/ulcdr5mDJL #Gold #XAUUSD
#
# -----
#
# Articles found: 49

# %%
# It looks like we were able to eliminate some false negatives (the number of articles rose from 23 to 49) while controlling for the false positives just by adding more words to the patterns.

# %%
# Tweaking this approach further (i.e., adding more words to the patterns) would probably yield even better results, meaning even fewer false negatives ceteris paribus (i.e., for the same amount of false positives), but I decided to stop here.
